# %% [markdown]
# ## Name classification with Keras
#
# In this example we will try to reproduce the results presented in [this paper](https://www.ijcai.org/proceedings/2017/0289.pdf).
#
# The dataset that we will use in this example can be downloaded from [here](https://www.dropbox.com/sh/ksvlzdh72ildhih/AAB5XhAwzo18CsoMDweaj11fa?dl=0)
#
# Place the two files into a directory called `data`. In addition, create a second directory called `data_processed`.
#
# The directory structure should be:
#
# ```
# ├── Step01_preprocess_names.ipynb
# ├── Step02_Build_Model.ipynb
# ├── Step03_classify_name.ipynb
# ├── data
# │   ├── country2ethnicity.txt
# │   └── countryResult.txt
# └── data_processed
# ```
#
# The authors classify names of athletes using a stack of `lstms` with a clever initialization.
#
# Let's start by having a look to the data.

# %% [markdown]
# ## 1-Data Preparation

# %%
import numpy as np
import pandas as pd
import pickle
import gensim
import nltk
import re
import os

from random import shuffle
from itertools import chain
from nltk import ngrams
from gensim.models import Word2Vec
from bs4 import BeautifulSoup
from tqdm import tqdm
from sklearn.model_selection import train_test_split

from keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, Embedding, Flatten, LSTM, Dense
from keras.layers.merge import concatenate
from keras.models import Model
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.metrics import top_k_categorical_accuracy

# %%
raw_data_file = "./data/countryResult.txt"
data_dir = "./data_processed"
dataset = open(raw_data_file).read().strip().split('\n')

# %% [markdown]
# We have 31595 records

# %%
print(len(dataset))
dataset[:5]
# Out:
# 31595
# ['Belarus\tBeijing 2008\tsilver\t20.28\tAthletics\tNatallia MIKHNEVICH/',
#  'Belarus\tVancouver 2010\tsilver\t48:32.0\tBiathlon\tSergey NOVIKOV/',
#  'Belarus\tBeijing 2008\tsilver\t8551\tAthletics\tAndrei KRAUCHANKA/',
#  'Belarus\tVancouver 2010\tgold\tFINAL\tFreestyle Skiing\tAlexei GRISHIN/',
#  'Belarus\tBeijing 2008\tbronze\t81.51\tAthletics\tIvan TSIKHAN/']

# %% [markdown]
# Let's clean the data and build more functional objects/dictionaries

# %%
remove_chars = [':', '©', '¶']
def clean_names(name):
    name_text = BeautifulSoup(name).get_text()
    name_text = re.sub("[^a-zA-Z\'.']"," ", name_text)
    name_text = re.sub(" +"," ",name_text)
    name_text = name_text.strip()
    clean_name = name_text.title()
    return clean_name

# %%
name2country = dict()
name2year = dict()
for line in tqdm(dataset):
    try:
        country, olympic_year, medal, record, sports, names_raw = line.split('\t')
        country = country.replace(',', ' ')
        country = country.strip()
    except ValueError as e:
        pass
    # In the olympics one has teams (i.e more than one individual per row)
    if len(names_raw.split('/')) >= 2:
        names = names_raw.split('/')
        names = [n for n in names if n!=""]
        for name in names:
            c_name = clean_names(name)
            if c_name in name2country:
                # and some athlete change countries. We keep the most recent nationality
                if country != name2country[c_name]:
                    previous_year = int(name2year[c_name].split(' ')[-1])
                    current_year  = int(olympic_year.split(' ')[-1])
                    if  previous_year <= current_year:
                        continue
                    else:
                        pass
            name2country[c_name] = country
            name2year[c_name] = olympic_year
# Out:
# 100%|██████████| 31595/31595 [01:34<00:00, 335.25it/s]

# %% [markdown]
# During the cleaning we lose 14k observations approximately. This is partially due to the fact that the cleaning above is fairly "rough". I will leave to you to carry on a better cleaning of the data so we keep more observations

# %%
len(name2country)
# Out:
# 17715

# %% [markdown]
# Let's have a look to the cleaned text

# %%
name2country
# Out:
# {'Natallia Mikhnevich': 'Belarus',
#  'Sergey Novikov': 'Belarus',
#  'Andrei Krauchanka': 'Belarus',
#  'Alexei Grishin': 'Belarus',
#  'Ivan Tsikhan': 'Belarus',
#  'Maryna Shkermankova': 'Belarus',
#  'Vadim Devyatovskiy': 'Belarus',
#  'Iryna Kulesha': 'Belarus',
#  'Aksana Miankova': 'Belarus',
#  'Darya Domracheva': 'Belarus',
#  'Fernanda Ribeiro': 'Portugal',
#  'Rui Silva': 'Portugal',
#  'Nelson Evora': 'Portugal',
#  'Rosa Mota': 'Portugal',
#  'Jose Manuel Gentil Quina': 'Portugal',
#  'Mario Gentil Quina': 'Portugal',
#  'Armando Da Silva Marques': 'Portugal',
#  'Fernando Silva Paes': 'Portugal',
#  'Francisco Valadas': 'Portugal',
#  'Luiz Silva': 'Portugal',
#  'Sergio Paulinho': 'Portugal',
#  'Nuno Barreto': 'Portugal',
#  'Victor Hugo Rocha': 'Portugal',
#  'Emanuel Silva': 'Portugal',
#  'Fernando Pimenta': 'Portugal',
#  'Domingos De Sousa Coutinho Marques Do Funchal': 'Portugal',
#  'Jose Beltrao': 'Portugal',
#  'Carlos Lopes': 'Portugal',
#  'Francis Obikwelu': 'Portugal',
#  "Duarte M.D'Almeida Bello": 'Portugal',
#  'Fernando Pinto Coelho Bello': 'Portugal',
#  'Nuno Delgado': 'Portugal',
#  'Vanessa Fernandes': 'Portugal',
#  "Antonio Borges D'Almeida": 'Portugal',
#  'Helder De Souza Martins': 'Portugal',
#  "Jos Mouzinho D'Albuquerque": 'Portugal',
#  'Antonio Leitao': 'Portugal',
#  'Francisco Rebello De Andrade': 'Portugal',
#  'Joaquim Mascarenhas De M. Fiuza': 'Portugal',
#  'Roel Velasco': 'Philippines',
#  'Leopoldo Serantes': 'Philippines',
#  'Teofilo Yldefonso': 'Philippines',
#  'Miguel S. White': 'Philippines',
#  'Jose Villanueva': 'Philippines',
#  'Mansueto Velasco': 'Philippines',
#  'Anthony N. Villanueva': 'Philippines',
#  'Simeon Galvez Toribio': 'Philippines',
#  'Mohammad Nassiri Seresht': 'Islamic Republic Of Iran',
#  'Abdollah Movahed Ardabili': 'Islamic Republic Of Iran',
#  'Mohammad Ali Sanatkaran': 'Islamic Republic Of Iran',
#  'Ebrahim Javadipour': 'Islamic Republic Of Iran',
#  'Jafar Mohammad Salmassi': 'Islamic Republic Of Iran',
#  'Sadegh Saeed Goudarzi': 'Islamic Republic Of Iran',
#  'Mahmoud Namdjou': 'Islamic Republic Of Iran',
#  'Mohammad Mehdi Yaghoubi': 'Islamic Republic Of Iran',
#  'Seyedmorad Mohammadi': 'Islamic Republic Of Iran',
#  'Behdad Salimikordasiabi': 'Islamic Republic Of Iran',
#  'Hadi Saei': 'Islamic Republic Of Iran',
#  'Alireza Rezaei': 'Islamic Republic Of Iran',
#  'Parviz Jalayer': 'Islamic Republic Of Iran',
#  'Masuod Jokar': 'Islamic Republic Of Iran',
#  'Gholam Reza Takhti': 'Islamic Republic Of Iran',
#  'Sajjad Anoushiravani Hamlabad': 'Islamic Republic Of Iran',
#  'Alireza Dabir': 'Islamic Republic Of Iran',
#  'Rahim Aliabadi': 'Islamic Republic Of Iran',
#  'Emamali Habibi Goudarzi': 'Islamic Republic Of Iran',
#  'Mahmoud Mollaghassemi': 'Islamic Republic Of Iran',
#  'Ghasem Gholamreza Rezaei': 'Islamic Republic Of Iran',
#  'Mansour Barzegar': 'Islamic Republic Of Iran',
#  'Amir Reza Khadem Azghadi': 'Islamic Republic Of Iran',
#  'Mohammad Bagheri Motamed': 'Islamic Republic Of Iran',
#  'Asgari Mohammadian': 'Islamic Republic Of Iran',
#  'Said Ali Akbar Haydari': 'Islamic Republic Of Iran',
#  'Esmail Elm Khah': 'Islamic Republic Of Iran',
#  'Djahanbakte Tovfighe': 'Islamic Republic Of Iran',
#  'Ali Mirzai': 'Islamic Republic Of Iran',
#  'Alireza Heidari': 'Islamic Republic Of Iran',
#  'Ehsan Naser Lashgari': 'Islamic Republic Of Iran',
#  'Mohammad Paziraye': 'Islamic Republic Of Iran',
#  'Kianoush Rostami': 'Islamic Republic Of Iran',
#  'Abdollah Modjtabavi': 'Islamic Republic Of Iran',
#  'Komeil Ghasemi': 'Islamic Republic Of Iran',
#  'Abutaleb Gorgori': 'Islamic Republic Of Iran',
#  'Hossein Tavakoli': 'Islamic Republic Of Iran',
#  'Shamseddin Seyed Abbassi': 'Islamic Republic Of Iran',
#  'Hossein Reza Zadeh': 'Islamic Republic Of Iran',
#  'Omid Haji Noroozi': 'Islamic Republic Of Iran',
#  'Mohammad Ali Khojastehpour': 'Islamic Republic Of Iran',
#  'Hamid Mohammad Soryan Reihanpour': 'Islamic Republic Of Iran',
#  'Mohammad Ebrahim Saifpour Saidabadi': 'Islamic Republic Of Iran',
#  'Ehsan Hadadi': 'Islamic Republic Of Iran',
#  'Nasser Guivegtchi': 'Islamic Republic Of Iran',
#  'Navab Nasirshelal': 'Islamic Republic Of Iran',
#  'Rasul Khadem Azghadi': 'Islamic Republic Of Iran',
#  'Abbas Jadidi': 'Islamic Republic Of Iran',
#  'Yossef Karami': 'Islamic Republic Of Iran',
#  'Said Aouita': 'Morocco',
#  'Moulay Brahim Boutayeb': 'Morocco',
#  'Brahim Lahlafi': 'Morocco',
#  'Hicham El Guerrouj': 'Morocco',
#  'Nawal El Moutawakel': 'Morocco',
#  'Nouzha Bidouane': 'Morocco',
#  'Abdalaati Iguider': 'Morocco',
#  'Jaouad Gharib': 'Morocco',
#  'Rachid El Basir': 'Morocco',
#  'Ali Ezzine': 'Morocco',
#  'Khalid Boulami': 'Morocco',
#  'Hasna Benhassi': 'Morocco',
#  'Tahar Tamsamani': 'Morocco',
#  'Mohamed Achik': 'Morocco',
#  'Abdelhak Achik': 'Morocco',
#  'Salah Hissou': 'Morocco',
#  'Abdesiem Rhadi Ben Abdesselem': 'Morocco',
#  'Khalid Skah': 'Morocco',
#  'Aidyn Smagulov': 'Kyrgyzstan',
#  'Ruslan Tiumenbaev': 'Kyrgyzstan',
#  'Kanatbek Begaliev': 'Kyrgyzstan',
#  'Minarti Timur': 'Indonesia',
#  'Tri Kushanjanto': 'Indonesia',
#  'Sri Indriyani': 'Indonesia',
#  'Candra Wijaya': 'Indonesia',
#  'Tony Gunawan': 'Indonesia',
#  'Soni Dwi Kuncoro': 'Indonesia',
#  'Eng Hian': 'Indonesia',
#  'Flandy Limpele': 'Indonesia',
#  'Raema Lisa Rumbewas': 'Indonesia',
#  'Winarni Binti Slamet': 'Indonesia',
#  'Ardy Bernardus Wiranata': 'Indonesia',
#  'Mia Audina': 'Indonesia',
#  'Triyatno': 'Indonesia',
#  'Alan Budi Kusuma': 'Indonesia',
#  'Rexy Ronald Mainaky': 'Indonesia',
#  'Ricky Achmad Subagja': 'Indonesia',
#  'Eko Yuli Irawan': 'Indonesia',
#  'Hendrawan': 'Indonesia',
#  'Hermawan Susanto': 'Indonesia',
#  'Hendra Setiawan': 'Indonesia',
#  'Markis Kido': 'Indonesia',
#  'Antonius Irianto': 'Indonesia',
#  'Denny Kantono': 'Indonesia',
#  'Maria Kristin Yulianti': 'Indonesia',
#  'Eddy Hartono': 'Indonesia',
#  'Rudy Gunawan': 'Indonesia',
#  'Susi Susanti': 'Indonesia',
#  'Kusuma Wardhani': 'Indonesia',
#  'Lilies Handayani': 'Indonesia',
#  'Nurfitriyana Saiman': 'Indonesia',
#  'Irawan Eko Yuli': 'Indonesia',
#  'Liliyana': 'Indonesia',
#  'Nova Widianto': 'Indonesia',
#  'Triyatno Triyatno': 'Indonesia',
#  'Taufik Hidayat': 'Indonesia',
#  'Marc Girardelli': 'Luxembourg',
#  'Joseph Alzin': 'Luxembourg',
#  'Joseph Barthel': 'Luxembourg',
#  'Cesar Mendoza': 'Chile',
#  'Oscar Cristi Gallo': 'Chile',
#  'Ricardo Echeverria': 'Chile',
#  'Manuel Plaza Reyes': 'Chile',
#  'Laure Manaudou': 'France',
#  'Waydelich': 'France',
#  'Marc Pajot': 'France',
#  'Yves Pajot': 'France',
#  'Alain Bernard': 'France',
#  'Charles Perrin': 'France',
#  'Daniel Soubeyran': 'France',
#  'Emile Wegelin': 'France',
#  'Georges Lumpp': 'France',
#  'Fernand Canteloube': 'France',
#  'Christophe Capelle': 'France',
#  'Francis Moreau': 'France',
#  'Jean Michel Monin': 'France',
#  'Philippe Ermenault': 'France',
#  'Hubert Parot': 'France',
#  'Jean Marcel Rozier': 'France',
#  'Marc Roguet': 'France',
#  'Michel Roche': 'France',
#  'Georges Andre': 'France',
#  'Bernard Morel': 'France',
#  'Jacques Lefevre': 'France',
#  'Jean Francois Tournon': 'France',
#  'Jean Laroyenne': 'France',
#  'Jean Levavasseur': 'France',
#  'Maurice Piot': 'France',
#  'Bough Ra Mohamed El Ouafi': 'France',
#  'Marie Jose Perec': 'France',
#  'Michel Bury': 'France',
#  'Field': 'France',
#  'Thierry Vigneron': 'France',
#  'Bruno Boscherie': 'France',
#  'Didier Flament': 'France',
#  'Frederic Pietruszka': 'France',
#  'Pascal Jolyot': 'France',
#  'Philippe Bonin': 'France',
#  'Jean Claude Olry': 'France',
#  'Jean Louis Olry': 'France',
#  'Paul Fritsch': 'France',
#  'Lise Legrand': 'France',
#  'Bruno Mingeon': 'France',
#  'Emanuel Hostache': 'France',
#  'Eric Le Chanony': 'France',
#  'Max Robert': 'France',
#  'Jean Pierre Amat': 'France',
#  'Victor Thibaud': 'France',
#  'Margit Otto Crepin': 'France',
#  'Guy P Rillat': 'France',
#  'Arnaud Tournant': 'France',
#  'Gregory Bauge': 'France',
#  'Kevin Sireau': 'France',
#  'Lucien Merignac': 'France',
#  'Ferreol Cannard': 'France',
#  'Julien Robert': 'France',
#  'Raphael Poiree': 'France',
#  'Vincent Defrasne': 'France',
#  'Gilbert Chapron': 'France',
#  'Herv Flandin': 'France',
#  'Lionel Laurent': 'France',
#  'Patrice Bailly Salins': 'France',
#  'Thierry Dusserre': 'France',
#  'Bertrand Gille': 'France',
#  'Cedric Burdet': 'France',
#  'Cedric Paty': 'France',
#  'Christophe Kempe': 'France',
#  'Daniel Narcisse': 'France',
#  'Daouda Karaboue': 'France',
#  'Didier Dinart': 'France',
#  'Guillaume Gille': 'France',
#  'Jerome Fernandez': 'France',
#  'Joel Abati': 'France',
#  'Luc Abalo': 'France',
#  'Michael Guigou': 'France',
#  'Nikola Karabatic': 'France',
#  'Olivier Girault': 'France',
#  'Thierry Omeyer': 'France',
#  'Andr Gaboriaud': 'France',
#  'Andr Labattut': 'France',
#  'Lucien Gaudin': 'France',
#  'Philippe Cattiau': 'France',
#  'Raymond P. Flacher': 'France',
#  'Roger Fran Ois Ducret': 'France',
#  'Jean R. Borotra': 'France',
#  'Jean Ren Lacoste': 'France',
#  'Christophe Tiozzo': 'France',
#  'Jacques Baptiste Lebrun': 'France',
#  'Bruno Carabetta': 'France',
#  'Xavier Fran Ois Lesage': 'France',
#  'Florence Masnada': 'France',
#  'E. Michelet': 'France',
#  'F. Michelet': 'France',
#  'Jean Christophe Rolland': 'France',
#  'Michel Andrieux': 'France',
#  'Paul Ren Colas': 'France',
#  'Jean Claude Brondani': 'France',
#  'Ernest Barberolle': 'France',
#  'Eug Ne Constant': 'France',
#  'Georges Lecointe': 'France',
#  'Louis A. Gressier': 'France',
#  'Raymond Talleux': 'France',
#  'Albert Ayat': 'France',
#  'Claude Bourquard': 'France',
#  'Claude Brodin': 'France',
#  'Jacques Brodin': 'France',
#  'Jacques Guittet': 'France',
#  'Yves Dreyfus': 'France',
#  'Anne Briand Bouthiaux': 'France',
#  'Corinne Niogret': 'France',
#  'Delphyne Burlet': 'France',
#  'V Ronique Claudel': 'France',
#  'Guy Drut': 'France',
#  'Michel Nowak': 'France',
#  'Andre Rene Jousseaume': 'France',
#  'Charles Louis Pierre Marion': 'France',
#  'Delphine Racinet': 'France',
#  'Joel Chenal': 'France',
#  'Alain Mimoun': 'France',
#  'L On Johnson': 'France',
#  "Christian D'Oriola": 'France',
#  'Didier Faivre Pierret': 'France',
#  'Herve Boussard': 'France',
#  'Jean Louis Harel': 'France',
#  'Philippe Gaumont': 'France',
#  'Jean Claude Killy': 'France',
#  'Andr Regaud': 'France',
#  'Henri Bonnefoy': 'France',
#  'L On Lecuyer': 'France',
#  'Louis Perree': 'France',
#  'Pierre Louis Bertran De Balanda': 'France',
#  'Alain Portes': 'France',
#  'Denis Lathoud': 'France',
#  'Denis Tristant': 'France',
#  'Eric Quintin': 'France',
#  'Frederic Perez': 'France',
#  'Frederic Volle': 'France',
#  'Gael Monthurel': 'France',
#  'Jackson Richardson': 'France',
#  'Jean Luc Thiebaut': 'France',
#  'Laurent Munier': 'France',
#  'Pascal Mahe': 'France',
#  'Philippe Debureau': 'France',
#  'Philippe Gardent': 'France',
#  'Philippe Medard': 'France',
#  'Stephane Stoecklin': 'France',
#  'Thierry Perreux': 'France',
#  'A. Albert': 'France',
#  'A. Roosevelt': 'France',
#  'Albert Henriquez': 'France',
#  'Alexandre Pharamond': 'France',
#  'Andr Rischmann': 'France',
#  'Auguste Giroux': 'France',
#  'Charles Gondouin': 'France',
#  'Frantz Reichel': 'France',
#  'G. Gautier': 'France',
#  'J. Herve': 'France',
#  'Jean Binoche': 'France',
#  'Jean Collas': 'France',
#  'Joseph Olivier': 'France',
#  'Lefebvre Hubert': 'France',
#  'Sarrade': 'France',
#  'Victor Larchandet': 'France',
#  'Vladimir Aitoff': 'France',
#  'Roger Beaufrand': 'France',
#  'Emile Ali Kahn': 'France',
#  'Ren Lorain': 'France',
#  'Ren Mourlon': 'France',
#  'Ren Tirard': 'France',
#  'Franck Adisson': 'France',
#  'Wilfrid Forgues': 'France',
#  'Marc Alexandre': 'France',
#  'Henri Cochet': 'France',
#  'Jacques Brugnon': 'France',
#  'Brigitte Latrille Gaudin': 'France',
#  'Christine Muzio': 'France',
#  'Isabelle Begard': 'France',
#  'Pascale Trinquet Hachin': 'France',
#  'Veronique Brouquier': 'France',
#  'Vencelas Dabaya Tientcheu': 'France',
#  'Bach': 'France',
#  'Duparc': 'France',
#  'Fernand Canelle': 'France',
#  'Fraysse': 'France',
#  'Gaillard': 'France',
#  'Grandjean': 'France',
#  'Huteau': 'France',
#  'Jean Bloch': 'France',
#  'Lambert': 'France',
#  'Macaire': 'France',
#  'Peltier': 'France',
#  'Pierre Allemane': 'France',
#  'Ren Garnier': 'France',
#  'Julien Absalon': 'France',
#  'Georges Buchard': 'France',
#  'Delphine Reau': 'France',
#  'Jacques Jean Guissart': 'France',
#  'Marc Emile Bouissou': 'France',
#  'Pierre Auguste Blondiaux': 'France',
#  'Roger Gautier': 'France',
#  'Catherine Plewinski': 'France',
#  'Philippe Riboud': 'France',
#  'Benedic': 'France',
#  'F. Cournollet': 'France',
#  'H. Aldeert': 'France',
#  'P. Canivet': 'France',
#  'R. Planque': 'France',
#  'Robert Boutigny': 'France',
#  'Gwladys Patience Epangue': 'France',
#  'L On Moreaux': 'France',
#  'Henri Deloge': 'France',
#  'Henri Gance': 'France',
#  'Maurice Larrouy': 'France',
#  'Alexandre Tufferi': 'France',
#  'Georges Taillandier': 'France',
#  'Georges Vallerey Jr.': 'France',
#  'Patrick Vial': 'France',
#  'Benjamin Varonian': 'France',
#  'Joseph Ventaja': 'France',
#  'Daniel Morelon': 'France',
#  'Georges Dransart': 'France',
#  'Marcel Renaud': 'France',
#  'Steeve Guenot': 'France',
#  'Sylvain Curinier': 'France',
#  'Paul Masson': 'France',
#  'Lionel Plumenail': 'France',
#  'Artur Mabellon': 'France',
#  'Eug Ne G. Grizot': 'France',
#  'Eug Ne Richez': 'France',
#  'Julien Louis Brule': 'France',
#  'L On Epin': 'France',
#  'L Once Gaston Quentin': 'France',
#  'Pascal Fauvel': 'France',
#  'Paul Leroy': 'France',
#  'Amaury Leveaux': 'France',
#  'Clement Lefert': 'France',
#  'Fabien Gilot': 'France',
#  'Jeremy Stravius': 'France',
#  'Yannick Agnel': 'France',
#  'Andr E Brunet': 'France',
#  'Pierre Brunet': 'France',
#  'Philippe Vatuone': 'France',
#  'Tony Estanguet': 'France',
#  'Eug Ne Henri Gravelotte': 'France',
#  'Ernest Cadine': 'France',
#  'Doriane Vidal': 'France',
#  'Pierre Trentin': 'France',
#  'Christian No L': 'France',
#  'Jeannie Longo Ciprelli': 'France',
#  'B. Louis Segura': 'France',
#  'Perrine Pelen': 'France',
#  'Jacques Dupont': 'France',
#  'Jacky Avril': 'France',
#  'Fran Ois Bonlieu': 'France',
#  'Jerome Thomas': 'France',
#  'Georges Trombert': 'France',
#  'Henri Marie Raoul De Saint Germain': 'France',
#  'Jean Andr Lacroix': 'France',
#  'Jean Margraff': 'France',
#  'Jean Mondielli': 'France',
#  'Marc Marie Jean Perrodon': 'France',
#  'Didier Vavasseur': 'France',
#  'Francois Barouh': 'France',
#  'Pascal Boucherit': 'France',
#  'Philippe Boccara': 'France',
#  'Marielle Goitschel': 'France',
#  'Anne Caroline Graffe': 'France',
#  'Alexandre Lippmann': 'France',
#  'Armand Massard': 'France',
#  'Emile Moreau': 'France',
#  'Gaston Amson': 'France',
#  'Georges Casanova': 'France',
#  'Gustave Buchard': 'France',
#  'Jean Christophe Bette': 'France',
#  'Laurent Porchier': 'France',
#  'Xavier Dorfmann': 'France',
#  'Yves Hocde': 'France',
#  'Laure Pequegnot': 'France',
#  'Henri Tauzin': 'France',
#  'Alphonse Decuyper': 'France',
#  'Charles Treffel': 'France',
#  'Coulon': 'France',
#  'D Sir Merchez': 'France',
#  'Devenot': 'France',
#  'Fardelle': 'France',
#  'Favier': 'France',
#  'Henri Peslier': 'France',
#  'Leriche': 'France',
#  'Louis Laufray': 'France',
#  'Louis Martin': 'France',
#  'Paul Vasseur': 'France',
#  'Pesloy': 'France',
#  'Thomas Burgess': 'France',
#  'Roxana Maracineanu': 'France',
#  'Emile Torcheboeuf': 'France',
#  'Eug Ne Mougin': 'France',
#  'Florian Rousseau': 'France',
#  'Guy De Luget': 'France',
#  'Henri Jobier': 'France',
#  'Jacques Coutrot': 'France',
#  'Josef Peroteaux': 'France',
#  'Henri Oreiller': 'France',
#  'Michel Carrega': 'France',
#  'Charles Rampelberg': 'France',
#  'Claude Arabo': 'France',
#  'Laetitia Le Corguille': 'France',
#  'Jose Beyaert': 'France',
#  'Charles Alexandre Casimir Poulenard': 'France',
#  'Charles Louis Lelong': 'France',
#  'Pierre Failliot': 'France',
#  'Robert Schurrer': 'France',
#  "Jean Francois D'Orgeix": 'France',
#  'Marcel Jacques Boulenger': 'France',
#  'Laurent Gane': 'France',
#  'Joseph Roffo': 'France',
#  'Pierre Basset': 'France',
#  'Albert Rust': 'France',
#  'Daniel Xuereb': 'France',
#  'Didier Senac': 'France',
#  'Dominique Bijotat': 'France',
#  'Francois Brisson': 'France',
#  'Guy Lacombe': 'France',
#  'Jean Christophe Thouvenel': 'France',
#  'Jean Louis Zanon': 'France',
#  'Jean Philippe Rohr': 'France',
#  'Jean Claude Lemoult': 'France',
#  'Jose Toure': 'France',
#  'Michel Bensoussan': 'France',
#  'Michel Bibard': 'France',
#  'Patrice Garande': 'France',
#  'Patrick Cubaynes': 'France',
#  'Philippe Jeannol': 'France',
#  'William Ayache': 'France',
#  'Andr Henri Gobert': 'France',
#  'Maurice Germot': 'France',
#  'Arnaud Boiteau': 'France',
#  'Cedric Lyard': 'France',
#  'Didier Courreges': 'France',
#  'Jean Teulere': 'France',
#  'Nicolas Touzaint': 'France',
#  'L On Flameng': 'France',
#  'Hajnalka Kiraly Picot': 'France',
#  'Laura Flessel Colovic': 'France',
#  'Maureen Nisima': 'France',
#  'Sarah Daninthe': 'France',
#  'Thomas Bouhail': 'France',
#  'Philippe Candeloro': 'France',
#  'Frederique Jossinet': 'France',
#  'Berengere Schuh': 'France',
#  'Sophie Dodemont': 'France',
#  'Virginie Arnold': 'France',
#  'Charles Pac Me': 'France',
#  'Anna Gomis': 'France',
#  'Patrick Pera': 'France',
#  'Christine Arron': 'France',
#  'Muriel Hurtis Houairi': 'France',
#  'Sylviane Felix': 'France',
#  'Veronique Mang': 'France',
#  'Houben': 'France',
#  'Jean Leuillieux': 'France',
#  'Tartara': 'France',
#  'Alexandra Ledermann': 'France',
#  'Joseph Guillemot': 'France',
#  'Julien Bontemps': 'France',
#  'Andr Lauseig': 'France',
#  'Gaston Heuet': 'France',
#  'Henri Lauvaux': 'France',
#  'L. Lucien Dolques': 'France',
#  'Maurice Norland': 'France',
#  'Robert Marchal': 'France',
#  'Martin Fourcade': 'France',
#  'Charles Rigoulot': 'France',
#  'Albert Seigner': 'France',
#  'Bernard Meyer': 'France',
#  'J Cariou': 'France',
#  "Michel Dufourt D'Astafort": 'France',
#  'Arnaud Geyre': 'France',
#  'Maurice Moucheraud': 'France',
#  'Michel Vermeulen': 'France',
#  'Albert Weil': 'France',
#  'F Lix Picon': 'France',
#  'Robert Monier': 'France',
#  'Nathalie Lancien': 'France',
#  'Christine Kiki Caron': 'France',
#  '..... Daumain': 'France',
#  'Amelie Mauresmo': 'France',
#  'Louis Hildebrand': 'France',
#  'Alain Lebas': 'France',
#  'Andr Auffray': 'France',
#  'Aumoitte': 'France',
#  'Alphonse Kirchhoffer': 'France',
#  'Camille Muffat': 'France',
#  'Charlotte Bonnet': 'France',
#  'Coralie Balmy': 'France',
#  'Margaux Farrell': 'France',
#  'Mylene Lazare': 'France',
#  'Ophelie Cyrielle Etienne': 'France',
#  'A. Guerrier': 'France',
#  'Georges Mollard': 'France',
#  'Louis Breguet': 'France',
#  'P. Ganthier': 'France',
#  'R. Girardet': 'France',
#  'Jean Jacques Mounier': 'France',
#  'Colette Besson': 'France',
#  'Christine Goitschel': 'France',
#  'Andr Gardere': 'France',
#  'Edouard Gardere': 'France',
#  'Ren Bondoux': 'France',
#  'Ren Bougnol': 'France',
#  'Ren Lemoine': 'France',
#  'Bernard Bregeon': 'France',
#  'Patrick Lefoulon': 'France',
#  'Janou Lefevre': 'France',
#  "Pierre Jonqueres D'Oriola": 'France',
#  'Daniel Revenu': 'France',
#  'Michel Rousseau': 'France',
#  'Bernard Talvard': 'France',
#  'Gilles Berolatti': 'France',
#  'Jean Claude Magnan': 'France',
#  'Charles Collignon': 'France',
#  'Eug Ne Victor Olivier': 'France',
#  'Gaston Alibert': 'France',
#  'Henri Georges Berger': 'France',
#  'Maryvonne Dupureur': 'France',
#  'Frederic Dufour': 'France',
#  'Pascal Touron': 'France',
#  'Damien Touya': 'France',
#  'Andr Six': 'France',
#  'Adolphe Ren Bousquet': 'France',
#  'Alfred Eluere': 'France',
#  'Andr Chilo': 'France',
#  'Constant Lamaigniere': 'France',
#  'Curtet': 'France',
#  'Edouard Bader': 'France',
#  'Eug Ne Soulie': 'France',
#  'Fran Ois Bordes': 'France',
#  'Grenet': 'France',
#  'Jacques Forestier': 'France',
#  'Maurice Labeyrie': 'France',
#  'Raoul Thiercelin': 'France',
#  'Raymond Berrurier': 'France',
#  'Ren Crabos': 'France',
#  'Robert Levasseur': 'France',
#  'Robert Thierry': 'France',
#  'Am D Thube': 'France',
#  'Gaston Thube': 'France',
#  'Jacques Thube': 'France',
#  'Lucie Decosse': 'France',
#  'Louis Martinet': 'France',
#  'Unknown Cox': 'France',
#  'Barreur Inconnu': 'France',
#  'Waleff': 'France',
#  'Georges Tainturier': 'France',
#  'Lionel Liottel': 'France',
#  'Emilie Lepennec': 'France',
#  'Maurice Schilles': 'France',
#  'Fernand Vandernotte': 'France',
#  'Jean Marcel Cosmat': 'France',
#  'Marcel Chauvigne': 'France',
#  'Marcel Vandernotte': 'France',
#  'No L Vandernotte': 'France',
#  'Gustave Sandras': 'France',
#  'Jean Jacques Guyon': 'France',
#  'Andr Higelin': 'France',
#  'Rene Libeer': 'France',
#  'Armand Marcelle': 'France',
#  'Edouard Marcelle': 'France',
#  'Henri Pr Aux': 'France',
#  'Christophe Guenot': 'France',
#  'Nicolas Berthelot': 'France',
#  'Henri Eberhart': 'France',
#  'Annie Famose': 'France',
#  'Mehdi Baala': 'France',
#  'Antoine Richard': 'France',
#  'Herman Panzo': 'France',
#  'Pascal Barre': 'France',
#  'Patrick Barre': 'France',
#  'Daniel Sauton Robin': 'France',
#  'Pascal Gentil': 'France',
#  'H. Lefebvre': 'France',
#  'Georges Gandil': 'France',
#  'Sebastien Amiez': 'France',
#  'Pascal Tayot': 'France',
#  "Elisabeth D'Ayen": 'France',
#  'Suzanne Lenglen': 'France',
#  'Boris Steimetz': 'France',
#  'Frederick Bousquet': 'France',
#  'Gregory Mallet': 'France',
#  'Teddy Riner': 'France',
#  'Jean Galfione': 'France',
#  'Daniel Rebillard': 'France',
#  'Armand Blanchonnet': 'France',
#  'Georges Wambst': 'France',
#  'Ren Hamel': 'France',
#  'Alain Moineau': 'France',
#  'Jacques Baudrier': 'France',
#  'Jean Lebret': 'France',
#  'Marcotte': 'France',
#  'Valton': 'France',
#  'William Martin': 'France',
#  'Andr Vandelle': 'France',
#  'C. Mandrillon': 'France',
#  'G. Berthet': 'France',
#  'Maurice Mandrillon': 'France',
#  'Julie P. Vlasto': 'France',
#  'Louis Vernet': 'France',
#  'Deborah Anthonioz': 'France',
#  'Isabelle Duchesnay Dean': 'France',
#  'Paul Duchesnay': 'France',
#  'Gaston Antoine Mercier': 'France',
#  'Guy Guillabert': 'France',
#  'Rene Jacques Guissart': 'France',
#  'Yves Delacour': 'France',
#  'Mickael Bourgain': 'France',
#  'Felicia Ballanger': 'France',
#  'Emile Coste': 'France',
#  'Yave Cahard': 'France',
#  'Louis De Champsavin': 'France',
#  'Ren Duverger': 'France',
#  'Sylvain Guillaume': 'France',
#  'Luc Pillot': 'France',
#  'Thierry Peponnet': 'France',
#  'Franck Dumoulin': 'France',
#  'Andr Gaudin': 'France',
#  'Cauchy': 'France',
#  'Salins': 'France',
#  'Georges Dron': 'France',
#  'Rene Faye': 'France',
#  'Octave Lapize': 'France',
#  'Pierre Durand Jr.': 'France',
#  'Sautreau': 'France',
#  'Anthony Terras': 'France',
#  'Dorian Mortelette': 'France',
#  'Germain Chardin': 'France',
#  'Jacques Courtillat': 'France',
#  'Pierre Rodocanacho': 'France',
#  'Louis Hostin': 'France',
#  'Pierre Coquelin De Lisle': 'France',
#  'Jean Le Duc Decazes': 'France',
#  'Emile Billard': 'France',
#  'P. Perquer': 'France',
#  'Henri Helle': 'France',
#  'Celine Lebrun': 'France',
#  'Miguel Martinez': 'France',
#  'Guillaume Florent': 'France',
#  'Emile Allais': 'France',
#  'Virginie Heriot': 'France',
#  'Alexis Vastine': 'France',
#  'Marie Laure Brunet': 'France',
#  'Larbi Benboudaoud': 'France',
#  'Johin': 'France',
#  'Jean Gachet': 'France',
#  'Eug Ne Balme': 'France',
#  'Mathieu Gourdain': 'France',
#  'A. Fasani': 'France',
#  'Albert Deborgies': 'France',
#  'Albert Mayaud': 'France',
#  'Georges Rigal': 'France',
#  'Henri Padou Sr.': 'France',
#  'J. Perol': 'France',
#  'Jean Lasquin': 'France',
#  'No L Delberghe': 'France',
#  'Paul Dujardin': 'France',
#  'R. Bertrand': 'France',
#  'Robert Desmettre': 'France',
#  'Henri Laurent': 'France',
#  'Guy Robert Marie Lefrant': 'France',
#  'Jack Louis J. Le Goff': 'France',
#  'Jehan Raymond Le Roy': 'France',
#  'Bertrand Vecten': 'France',
#  'Daniel Fauche': 'France',
#  'Gilles Bosquet': 'France',
#  'Olivier Moncelet': 'France',
#  'Christine Cicot': 'France',
#  'Jehan Buhan': 'France',
#  'Nicolas Charbonnier': 'France',
#  'Olivier Bausset': 'France',
#  'Etchegaray': 'France',
#  'Maurice Durquetty': 'France',
#  'Hugues Duboscq': 'France',
#  'Bruno Marie Rose': 'France',
#  'Daniel Sangouma': 'France',
#  'Gilles Queneherve': 'France',
#  'Max Moriniere': 'France',
#  'Daniel Gillois': 'France',
#  'Gerard De Ballorre': 'France',
#  'Sebastien Foucras': 'France',
#  'Achille Paroche': 'France',
#  'Edgar Grospiron': 'France',
#  'Roger Michelot': 'France',
#  'Guy Lapebie': 'France',
#  'Robert Charpentier': 'France',
#  'Robert Dorgebray': 'France',
#  'Eric Srecki': 'France',
#  'Catherine Fleury Vachon': 'France',
#  'Jason Lamy Chappuis': 'France',
#  'Arnaud Di Pasquale': 'France',
#  'Mahiedine Mekhissi B.': 'France',
#  'Andr Castanet': 'France',
#  'Gaston Ragueneau': 'France',
#  'Jacques Chastanie': 'France',
#  'Michel Champoudry': 'France',
#  'Bernard Baudoux': 'France',
#  'Claude Netter': 'France',
#  'Jacques Lataste': 'France',
#  'Rene Coicaud': 'France',
#  'Roger Closset': 'France',
#  'Stephane Traineau': 'France',
#  'Benoit Caranobe': 'France',
#  'Florence Baverel Robert': 'France',
#  'Max Decugis': 'Mixed Team',
#  'Pierre Albarran': 'France',
#  'Charles Kouyos': 'France',
#  'Carole Merle': 'France',
#  'Paul Bontemps': 'France',
#  'Francois Schewetta': 'France',
#  'Jacques Lunis': 'France',
#  'Jean Kerebel': 'France',
#  "Robert Chef D'Hotel": 'France',
#  'Carole Montillet Carles': 'France',
#  'Louis Duffoy': 'France',
#  'Maurice Lecoq': 'France',
#  'Trinite': 'France',
#  'Dominique Maximien Garderes': 'France',
#  'Khedafi Djelkhir': 'France',
#  'Andre Barrais': 'France',
#  'Andre Buffiere': 'France',
#  'Andre Even': 'France',
#  'Fernand Guillou': 'France',
#  'Jacques Perrier': 'France',
#  'Lucien Robuffic': 'France',
#  'Maurice Desaymonnet': 'France',
#  'Maurice Girardot': 'France',
#  'Michel Bonnevie': 'France',
#  'Pierre Thiolon': 'France',
#  'Raymond Offner': 'France',
#  'Rene Chocat': 'France',
#  'Rene Derency': 'France',
#  'Yvan Quenin': 'France',
#  'Charles De Vendeville': 'France',
#  'Bernard Schmetz': 'France',
#  'Henri Dulieux': 'France',
#  'Michel Pecheux': 'France',
#  'Paul Wormser': 'France',
#  'Eric Navet': 'France',
#  'Herve Godignon': 'France',
#  'Hubert Bourdy': 'France',
#  'Michel Robert': 'France',
#  'Jean Francois Lamour': 'France',
#  'Aldo Eminente': 'France',
#  'Alexandre Jany': 'France',
#  'Jean Boiteux': 'France',
#  'Joseph Bernardo': 'France',
#  'Jean Gerard Saint Fort Paillard': 'France',
#  'Maurice Buret': 'France',
#  'Thierry Rey': 'France',
#  'Emile Fisseux': 'France',
#  'Charles Fr D Ric Petit': 'France',
#  'Anne Caroline Chausson': 'France',
#  'Auguste Serrurier': 'France',
#  'Frederic Delpla': 'France',
#  'Jean Michel Henry': 'France',
#  'Olivier Lenglet': 'France',
#  'Sandra Laoura': 'France',
#  'Christophe Gagliano': 'France',
#  'Jean Baptiste Mimiague': 'France',
#  'Jean Despeaux': 'France',
#  'Emile Bougnol': 'France',
#  'Pierre Quinon': 'France',
#  'Stephan Caron': 'France',
#  'Justinien De Clary': 'France',
#  'Benjamin Rondeau': 'France',
#  'Julien Despres': 'France',
#  'Albert Courquin': 'France',
#  'Andr Parmentier': 'France',
#  'Georges Roes': 'France',
#  'Pierre Hardy': 'France',
#  'Emile Rumeau': 'France',
#  'Raymond Suvigny': 'France',
#  'Jean Cugnot': 'France',
#  'Lucien Choury': 'France',
#  'Albert Seguin': 'France',
#  'Arthur Hermann': 'France',
#  'Eug Ne Cordonnier': 'France',
#  'Fran Ois Gangloff': 'France',
#  'Jean Gounot': 'France',
#  'Joseph Huber': 'France',
#  'L On Delsarte': 'France',
#  'Franck David': 'France',
#  'Lucien Michard': 'France',
#  'Emile Thubron': 'France',
#  'Antoine Erneste Vedrenne': 'France',
#  'Carlos Deltour': 'France',
#  'Raoul Paoli': 'France',
#  'Julie Bresset': 'France',
#  'Jean Yves Le Deroff': 'France',
#  'Nicolas Henard': 'France',
#  'Georges Morel': 'France',
#  'Jacques Morel': 'France',
#  'Jean Claude Derouy': 'France',
#  'Franck Esposito': 'France',
#  'Fernand Jourdant': 'France',
#  'Jean Piot': 'France',
#  'Fernand Sanz': 'France',
#  'Andre Giriat': 'France',
#  'Anselme Brusa': 'France',
#  'Didier Hoyer': 'France',
#  'Olivier Boivin': 'France',
#  'Albert Xavier Eluere': 'France',
#  'Jacqueline Mazeas': 'France',
#  'Rene Schiermeyer': 'France',
#  'Thibaud Chapelle': 'France',
#  'Ghani Yolouz': 'France',
#  'A. Mcevoy': 'France',
#  'A.J. Schneidau': 'France',
#  'D. Robinson': 'France',
#  'F. Roques': 'France',
#  'Henry John Terry': 'France',
#  'J. Braid': 'France',
#  'P.H. Tomalin': 'France',
#  'R. Horne': 'France',
#  'T.H. Jordan': 'France',
#  'W. Anderson': 'France',
#  'W. Browning': 'France',
#  'W.T. Attrill': 'France',
#  'Robert Leroux': 'France',
#  'Florence Steurer': 'France',
#  'Fabrice Guy': 'France',
#  'Ludovic Roux': 'France',
#  'Nicolas Bal': 'France',
#  'Joseph Gonzales': 'France',
#  'L On See': 'France',
#  'Jean Goujon': 'France',
#  'Roger Le Nizerhy': 'France',
#  'David Douillet': 'France',
#  'Frederic Kowal': 'France',
#  'Samuel Barathay': 'France',
#  'Claude Auguste Martin': 'France',
#  'Guy Fernand Nosbaum': 'France',
#  'Jean Klein': 'France',
#  'Robert Dumontois': 'France',
#  'Marion Clignet': 'France',
#  'Lucien Demanet': 'France',
#  'Joel Bettin': 'France',
#  'Philippe Renaud': 'France',
#  'Philippe Omnes': 'France',
#  'Bernard Laidebeur': 'France',
#  'Claude Piquemal': 'France',
#  'Jocelyn Delecour': 'France',
#  'Paul Genevay': 'France',
#  'Yves Loday': 'France',
#  'Jean Boudehen': 'France',
#  'Michel Chapuis': 'France',
#  'Angelo Parisi': 'Great Britain',
#  'Antoine Deneriaz': 'France',
#  'Florent Manaudou': 'France',
#  'Karine Ruby': 'France',
#  'Emile Mercier': 'France',
#  'Brice Guyart': 'France',
#  'Jean Noel Ferrari': 'France',
#  'Patrice Lhotellier': 'France',
#  'Henri Arthus': 'France',
#  'Louis Potheau': 'France',
#  'Pierre Rabot': 'France',
#  'Edmond Decottignies': 'France',
#  'Vincent Jay': 'France',
#  'Micheline Ostermeyer': 'France',
#  'Frederic Cottier': 'France',
#  'Philippe Boisse': 'France',
#  'Jean Ces': 'France',
#  'Eric Poujade': 'France',
#  'Achille Souchard': 'France',
#  'Georges Detreille': 'France',
#  'Marcel Gobillot': 'France',
#  'Jean Christophe Peraud': 'France',
#  'Charles Coste': 'France',
#  'Fernand Decanali': 'France',
#  'Pierre Adam': 'France',
#  'Serge Blusson': 'France',
#  'Adolphe Jaureguy': 'France',
#  'Aim Cassayet': 'France',
#  'Albert Dupouy': 'France',
#  'Alexandre Bioussa': 'France',
#  'Andr Behoteguy': 'France',
#  'C. Gonnet': 'France',
#  'C. Montade': 'France',
#  'Cl Ment Dupont': 'France',
#  'E. Frayssinet': 'France',
#  'E. Ribere': 'France',
#  'Etienne Bonnes': 'France',
#  'Etienne Piquiral': 'France',
#  'F. Abraham': 'France',
#  'F. Cayrol': 'France',
#  'F. Clauzel': 'France',
#  'Fran Ois Borde': 'France',
#  'Gilbert Gerentes': 'France',
#  'Henri Galau': 'France',
#  'Jean Bayard': 'France',
#  'Jean Etcheberry': 'France',
#  'Jean Vaysse': 'France',
#  'L. Lepatey': 'France',
#  'Louis Beguet': 'France',
#  'M. Besson': 'France',
#  'Marcel Fr D Ric Lubin Lebr Re': 'France',
#  'R. Piteu': 'France',
#  'Raoul Got': 'France',
#  'Ren Araou': 'France',
#  'Ren Lasserre': 'France',
#  'L O Lacroix': 'France',
#  'Adrien Hardy': 'France',
#  'Sebastien Vieilledent': 'France',
#  'Jean Graczyk': 'France',
#  'Jean Claude Lecante': 'France',
#  'Rene Bianchi': 'France',
#  'Gilbert Bozon': 'France',
#  'Nicolas Lopez': 'France',
#  'Lionel Bony De Castellane': 'France',
#  'Marcel Perrot': 'France',
#  'Paul Winter': 'France',
#  'Alfred Ple': 'France',
#  'Gaston Giran': 'France',
#  'Jacqueline Du Bief': 'France',
#  'Daniel Roger Velasques': 'France',
#  'Francis Kerbirou': 'France',
#  'Gilles Bertould': 'France',
#  'Jacques Carette': 'France',
#  'Bernard Robert Malivoire': 'France',
#  'Raymond Julien Salles': 'France',
#  'Charlot': 'France',
#  'Emile Delchambre': 'France',
#  'Henri Bouckaert': 'France',
#  'Henri Hazebrouck': 'France',
#  'Jean Cau': 'France',
#  'Auguste Cavadini': 'France',
#  'Ren Thomas': 'France',
#  'Amede Fournier': 'France',
#  'Henri Mouillefarine': 'France',
#  'Paul Chocque': 'France',
#  'Rene Legreves': 'France',
#  'Jo Wilfried Tsonga': 'France',
#  'Michael Llodra': 'France',
#  'Bertrand': 'France',
#  'Cadet': 'France',
#  'Maurice Hochepied': 'France',
#  ...}

# %%
country2idx = dict([(cntr,i) for i,cntr in enumerate(sorted(set(name2country.values())))])
country2idx
# Out:
# {'Algeria': 0,
#  'Argentina': 1,
#  'Armenia': 2,
#  'Australasia (1908-1912)': 3,
#  'Australia': 4,
#  'Austria': 5,
#  'Azerbaijan': 6,
#  'Bahamas': 7,
#  'Belarus': 8,
#  'Belgium': 9,
#  'Brazil': 10,
#  'Bulgaria': 11,
#  'Canada': 12,
#  'Chile': 13,
#  'Chinese Taipei': 14,
#  'Colombia': 15,
#  'Croatia': 16,
#  'Cuba': 17,
#  'Czech Republic': 18,
#  'Czechoslovakia': 19,
#  "Democratic People's Republic Of Korea": 20,
#  'Denmark': 21,
#  'Egypt': 22,
#  'Estonia': 23,
#  'Ethiopia': 24,
#  'Federal Republic Of Germany (1950-1990  "GER" Since)': 25,
#  'Finland': 26,
#  'France': 27,
#  'Georgia': 28,
#  'German Democratic Republic (1955-1990': 29,
#  'Germany': 30,
#  'Great Britain': 31,
#  'Greece': 32,
#  'Guatemala': 33,
#  'Guyana': 34,
#  'Haiti': 35,
#  'Hong Kong  China': 36,
#  'Hungary': 37,
#  'Iceland': 38,
#  'Independant Participant': 39,
#  'India': 40,
#  'Indonesia': 41,
#  'Iraq': 42,
#  'Ireland': 43,
#  'Islamic Republic Of Iran': 44,
#  'Israel': 45,
#  'Italy': 46,
#  'Jamaica': 47,
#  'Japan': 48,
#  'Kazakhstan': 49,
#  'Kenya': 50,
#  'Kuwait': 51,
#  'Kyrgyzstan': 52,
#  'Latvia': 53,
#  'Lebanon': 54,
#  'Liechtenstein': 55,
#  'Lithuania': 56,
#  'Luxembourg': 57,
#  'Malaysia': 58,
#  'Mauritius': 59,
#  'Mexico': 60,
#  'Mixed Team': 61,
#  'Mongolia': 62,
#  'Montenegro': 63,
#  'Morocco': 64,
#  'Mozambique': 65,
#  'Namibia': 66,
#  'Netherlands': 67,
#  'Netherlands Antilles': 68,
#  'New Zealand': 69,
#  'Niger': 70,
#  'Nigeria': 71,
#  'Norway': 72,
#  'Pakistan': 73,
#  'Panama': 74,
#  'Paraguay': 75,
#  "People's Republic Of China": 76,
#  'Peru': 77,
#  'Philippines': 78,
#  'Poland': 79,
#  'Portugal': 80,
#  'Puerto Rico': 81,
#  'Qatar': 82,
#  'Republic Of Korea': 83,
#  'Republic Of Moldova': 84,
#  'Romania': 85,
#  'Russia': 86,
#  'Russian Federation': 87,
#  'Saudi Arabia': 88,
#  'Senegal': 89,
#  'Serbia': 90,
#  'Serbia And Montenegro': 91,
#  'Singapore': 92,
#  'Slovakia': 93,
#  'Slovenia': 94,
#  'South Africa': 95,
#  'Spain': 96,
#  'Sri Lanka': 97,
#  'Sudan': 98,
#  'Suriname': 99,
#  'Sweden': 100,
#  'Switzerland': 101,
#  'Syrian Arab Republic': 102,
#  'Tadjikistan': 103,
#  'Thailand': 104,
#  'The Former Yugoslav Republic Of Macedonia': 105,
#  'Togo': 106,
#  'Tonga': 107,
#  'Trinidad And Tobago': 108,
#  'Tunisia': 109,
#  'Turkey': 110,
#  'USSR': 111,
#  'Uganda': 112,
#  'Ukraine': 113,
#  'Unified Team (ex USSR)': 114,
#  'United Arab Emirates': 115,
#  'United Republic Of Tanzania': 116,
#  'United States Of America': 117,
#  'United Team Of Germany (1956 1960 1964)': 118,
#  'Uruguay': 119,
#  'Uzbekistan': 120,
#  'Venezuela': 121,
#  'Vietnam': 122,
#  'Virgin Islands  US': 123,
#  'Yugoslavia': 124,
#  'Zambia': 125,
#  'Zimbabwe': 126}

# %% [markdown]
# Save the resulst

# %%
pickle.dump(name2country, open(os.path.join(data_dir, 'name2country.p'), 'wb'))
pickle.dump(country2idx, open(os.path.join(data_dir,'country2idx.p'), 'wb'))

# %% [markdown]
# Let's now define a helper function to get the n-grams given a name. We will see later what these are used for

# %%
def get_ngram(corpus, n):
    n_grams = set()
    for strg in corpus:
        ngram_gen = ngrams(strg,n)
        for n_gram in ngram_gen:
            n_grams.add("".join(n_gram))
    return list(n_grams)

# %%
print(get_ngram(['javier'], 2))
print(get_ngram(['javier'], 3))
# Out:
# ['ie', 'vi', 'ja', 'av', 'er']
# ['jav', 'avi', 'vie', 'ier']

# %%
all_names = name2country.keys()
unigrams = sorted(list(set(" ".join(all_names))))
bigrams  = sorted(get_ngram(all_names, 2))
trigrams = sorted(get_ngram(all_names, 3))
unigram2idx = dict([(ng, i) for i,ng in enumerate(unigrams)])
bigram2idx  = dict([(ng, i) for i,ng in enumerate(bigrams)])
trigram2idx = dict([(ng, i) for i,ng in enumerate(trigrams)])

# %% [markdown]
# Save the resulst

# %%
pickle.dump(unigram2idx, open(os.path.join(data_dir,'unigram2idx.p'), 'wb'))
pickle.dump(bigram2idx, open(os.path.join(data_dir,'bigram2idx.p'), 'wb'))
pickle.dump(trigram2idx, open(os.path.join(data_dir,'trigram2idx.p'), 'wb'))

# %% [markdown]
# ## Building the Model
#
# with the aim of preserving order, let's move from dictionaries to tuples

# %%
# we need to preserve order, so dictionaries are not good...
tmp = list(name2country.items())
tmp = sorted(tmp, key=lambda tmp: tmp[0])
all_names, all_countries = [], []
for n, c in tmp:
    all_names.append(n)
    all_countries.append(c)
all_names[:10]
# Out:
# ['..... Daumain',
#  'A Lam Shin',
#  'A. Albert',
#  'A. B Gli',
#  'A. B. Zumelzu',
#  'A. Faehlmann',
#  'A. Fasani',
#  'A. Fauquet Lemaitre',
#  'A. Ferraris',
#  'A. Gilpin']

# %%
# Build corpus of ngrams with n=1,2,3
unig_corpus = [list((''.join(ng) for ng in ngrams(name, 1)))
               for name in all_names]
bigr_corpus = [list((''.join(ng) for ng in ngrams(name, 2)))
               for name in all_names]
trig_corpus = [list((''.join(ng) for ng in ngrams(name, 3)))
               for name in all_names]
bigr_corpus[:5]
# Out:
# [['..', '..', '..', '..', '. ', ' D', 'Da', 'au', 'um', 'ma', 'ai', 'in'],
#  ['A ', ' L', 'La', 'am', 'm ', ' S', 'Sh', 'hi', 'in'],
#  ['A.', '. ', ' A', 'Al', 'lb', 'be', 'er', 'rt'],
#  ['A.', '. ', ' B', 'B ', ' G', 'Gl', 'li'],
#  ['A.', '. ', ' B', 'B.', '. ', ' Z', 'Zu', 'um', 'me', 'el', 'lz', 'zu']]

# %%
unig_corpus
# Out:
# [['.', '.', '.', '.', '.', ' ', 'D', 'a', 'u', 'm', 'a', 'i', 'n'],
#  ['A', ' ', 'L', 'a', 'm', ' ', 'S', 'h', 'i', 'n'],
#  ['A', '.', ' ', 'A', 'l', 'b', 'e', 'r', 't'],
#  ['A', '.', ' ', 'B', ' ', 'G', 'l', 'i'],
#  ['A', '.', ' ', 'B', '.', ' ', 'Z', 'u', 'm', 'e', 'l', 'z', 'u'],
#  ['A', '.', ' ', 'F', 'a', 'e', 'h', 'l', 'm', 'a', 'n', 'n'],
#  ['A', '.', ' ', 'F', 'a', 's', 'a', 'n', 'i'],
#  ['A',
#   '.',
#   ' ',
#   'F',
#   'a',
#   'u',
#   'q',
#   'u',
#   'e',
#   't',
#   ' ',
#   'L',
#   'e',
#   'm',
#   'a',
#   'i',
#   't',
#   'r',
#   'e'],
#  ['A', '.', ' ', 'F', 'e', 'r', 'r', 'a', 'r', 'i', 's'],
#  ['A', '.', ' ', 'G', 'i', 'l', 'p', 'i', 'n'],
#  ['A', '.', ' ', 'G', 'u', 'e', 'r', 'r', 'i', 'e', 'r'],
#  ['A', '.', ' ', 'H', 'a', 's', 'l', 'a', 'm'],
#  ['A', '.', ' ', 'H', 'e', 'l', 'm', 'a', 'n'],
#  ['A', '.', ' ', 'H', 'e', 'n', 'r', 'y', ' ', 'T', 'h', 'o', 'm', 'a', 's'],
#  ['A', '.', ' ', 'L', 'a', 'w', 'r', 'e', 'y'],
#  ['A', '.', ' ', 'M', 'a', 'r', 'a'],
#  ['A', '.', ' ', 'M', 'a', 'r', 'i', 'a', 'c', 'h', 'e', 'r'],
#  ['A', '.', ' ', 'M', 'c', 'e', 'v', 'o', 'y'],
#  ['A', '.', ' ', 'M', 'e', 'l', 'o', 'g', 'n', 'o'],
#  ['A', '.', ' ', 'P', 'e', 'n', 'a'],
#  ['A', '.', ' ', 'R', 'i', 'e', 'g', 'e', 'r'],
#  ['A', '.', ' ', 'R', 'o', 'o', 's', 'e', 'v', 'e', 'l', 't'],
#  ['A', '.', ' ', 'V', 'i', 'v', 'i', 'a', 'n', 'o'],
#  ['A', '.', ' ', 'W', 'i', 'l', 'l', 'c', 'o', 'c', 'k', 's'],
#  ['A', '.', 'J', '.', ' ', 'S', 'c', 'h', 'n', 'e', 'i', 'd', 'a', 'u'],
#  ['A', 'a', 'g', 'e', ' ', 'B', 'i', 'r', 'c', 'h'],
#  ['A',
#   'a',
#   'g',
#   'e',
#   ' ',
#   'E',
#   'r',
#   'n',
#   's',
#   't',
#   ' ',
#   'L',
#   'a',
#   'r',
#   's',
#   'e',
#   'n'],
#  ['A', 'a', 'g', 'e', ' ', 'J', ' ', 'R', 'g', 'e', 'n', 's', 'e', 'n'],
#  ['A',
#   'a',
#   'g',
#   'e',
#   ' ',
#   'M',
#   'a',
#   'r',
#   'i',
#   'u',
#   's',
#   ' ',
#   'H',
#   'a',
#   'n',
#   's',
#   'e',
#   'n'],
#  ['A',
#   'a',
#   'g',
#   'e',
#   ' ',
#   'V',
#   'a',
#   'l',
#   'd',
#   'e',
#   'm',
#   'a',
#   'r',
#   ' ',
#   'H',
#   'a',
#   'r',
#   'a',
#   'l',
#   'd',
#   ' ',
#   'F',
#   'r',
#   'a',
#   'n',
#   'd',
#   's',
#   'e',
#   'n'],
#  ['A', 'a', 'g', 'e', ' ', 'W', 'a', 'l', 't', 'h', 'e', 'r'],
#  ['A', 'a', 'g', 'j', 'e', ' ', 'A', 'd', 'a', ' ', 'K', 'o', 'k'],
#  ['A', 'a', 'r', 'o', 'n', ' ', 'E', 'g', 'b', 'e', 'l', 'e'],
#  ['A', 'a', 'r', 'o', 'n', ' ', 'G', 'a', 't', 'e'],
#  ['A', 'a', 'r', 'o', 'n', ' ', 'M', 'c', 'i', 'n', 't', 'o', 's', 'h'],
#  ['A', 'a', 'r', 'o', 'n', ' ', 'P', 'e', 'i', 'r', 's', 'o', 'l'],
#  ['A', 'a', 'v', 'o', ' ', 'P', 'i', 'k', 'k', 'u', 'u', 's'],
#  ['A', 'b', 'a', 'z', ' ', 'A', 'r', 's', 'l', 'a', 'n', 'a', 'g', 'i', 'c'],
#  ['A', 'b', 'b', 'a', 's', ' ', 'J', 'a', 'd', 'i', 'd', 'i'],
#  ['A', 'b', 'b', 'o', 's', ' ', 'A', 't', 'o', 'e', 'v'],
#  ['A',
#   'b',
#   'd',
#   'a',
#   'l',
#   'a',
#   'a',
#   't',
#   'i',
#   ' ',
#   'I',
#   'g',
#   'u',
#   'i',
#   'd',
#   'e',
#   'r'],
#  ['A',
#   'b',
#   'd',
#   'e',
#   'l',
#   ' ',
#   'A',
#   'a',
#   'l',
#   ' ',
#   'A',
#   'h',
#   'm',
#   'e',
#   'd',
#   ' ',
#   'R',
#   'a',
#   's',
#   'h',
#   'e',
#   'd'],
#  ['A', 'b', 'd', 'e', 'l', 'h', 'a', 'k', ' ', 'A', 'c', 'h', 'i', 'k'],
#  ['A',
#   'b',
#   'd',
#   'e',
#   's',
#   'i',
#   'e',
#   'm',
#   ' ',
#   'R',
#   'h',
#   'a',
#   'd',
#   'i',
#   ' ',
#   'B',
#   'e',
#   'n',
#   ' ',
#   'A',
#   'b',
#   'd',
#   'e',
#   's',
#   's',
#   'e',
#   'l',
#   'e',
#   'm'],
#  ['A',
#   'b',
#   'd',
#   'o',
#   'l',
#   'l',
#   'a',
#   'h',
#   ' ',
#   'M',
#   'o',
#   'd',
#   'j',
#   't',
#   'a',
#   'b',
#   'a',
#   'v',
#   'i'],
#  ['A',
#   'b',
#   'd',
#   'o',
#   'l',
#   'l',
#   'a',
#   'h',
#   ' ',
#   'M',
#   'o',
#   'v',
#   'a',
#   'h',
#   'e',
#   'd',
#   ' ',
#   'A',
#   'r',
#   'd',
#   'a',
#   'b',
#   'i',
#   'l',
#   'i'],
#  ['A', 'b', 'd', 'o', 'n', ' ', 'P', 'a', 'm', 'i', 'c', 'h'],
#  ['A', 'b', 'd', 'o', 'u', 'l', 'a', 'y', 'e', ' ', 'S', 'e', 'y', 'e'],
#  ['A',
#   'b',
#   'd',
#   'u',
#   'l',
#   ' ',
#   'W',
#   'a',
#   'h',
#   'i',
#   'd',
#   ' ',
#   'A',
#   'z',
#   'i',
#   'z'],
#  ['A',
#   'b',
#   'd',
#   'u',
#   'l',
#   'l',
#   'a',
#   'h',
#   ' ',
#   'W',
#   'a',
#   'l',
#   'e',
#   'e',
#   'd',
#   ' ',
#   'S',
#   'h',
#   'a',
#   'r',
#   'b',
#   'a',
#   't',
#   'l',
#   'y'],
#  ['A',
#   'b',
#   'd',
#   'u',
#   'l',
#   'l',
#   'o',
#   ' ',
#   'T',
#   'a',
#   'n',
#   'g',
#   'r',
#   'i',
#   'e',
#   'v'],
#  ['A', 'b', 'e', 'b', 'e', ' ', 'B', 'i', 'k', 'i', 'l', 'a'],
#  ['A',
#   'b',
#   'e',
#   'l',
#   ' ',
#   'K',
#   'i',
#   'p',
#   'r',
#   'o',
#   'p',
#   ' ',
#   'M',
#   'u',
#   't',
#   'a',
#   'i'],
#  ['A', 'b', 'e', 'l', ' ', 'K', 'i', 'r', 'u', 'i'],
#  ['A',
#   'b',
#   'e',
#   'l',
#   ' ',
#   'R',
#   'i',
#   'c',
#   'a',
#   'r',
#   'd',
#   'o',
#   ' ',
#   'L',
#   'a',
#   'u',
#   'd',
#   'o',
#   'n',
#   'i',
#   'o'],
#  ['A',
#   'b',
#   'e',
#   'l',
#   'a',
#   'r',
#   'd',
#   'o',
#   ' ',
#   'O',
#   'l',
#   'i',
#   'v',
#   'i',
#   'e',
#   'r'],
#  ['A', 'b', 'h', 'i', 'n', 'a', 'v', ' ', 'B', 'i', 'n', 'd', 'r', 'a'],
#  ['A', 'b', 'i', 'o', 'd', 'o', 'n', ' ', 'O', 'b', 'a', 'f', 'e', 'm', 'i'],
#  ['A', 'b', 'r', 'a', 'h', 'a', 'm', ' ', 'C', 'h', 'a', 'r', 'i', 't', 'e'],
#  ['A', 'b', 'r', 'a', 'h', 'a', 'm', ' ', 'K', 'u', 'r', 'l', 'a', 'n', 'd'],
#  ['A', 'b', 'r', 'a', 'm', 'o', ' ', 'A', 'l', 'b', 'i', 'n', 'i'],
#  ['A',
#   'b',
#   'u',
#   't',
#   'a',
#   'l',
#   'e',
#   'b',
#   ' ',
#   'G',
#   'o',
#   'r',
#   'g',
#   'o',
#   'r',
#   'i'],
#  ['A', 'c', 'e', ' ', 'R', 'u', 's', 'e', 'v', 's', 'k', 'i'],
#  ['A', 'c', 'e', 'r', ' ', 'N', 'e', 't', 'h', 'e', 'r', 'c', 'o', 't', 't'],
#  ['A',
#   'c',
#   'h',
#   'i',
#   'l',
#   'l',
#   'e',
#   ' ',
#   'C',
#   '.',
#   ' ',
#   'M',
#   '.',
#   ' ',
#   'T',
#   'r',
#   'i',
#   'b',
#   'o',
#   'u',
#   'i',
#   'l',
#   'l',
#   'e',
#   't'],
#  ['A', 'c', 'h', 'i', 'l', 'l', 'e', ' ', 'P', 'a', 'r', 'o', 'c', 'h', 'e'],
#  ['A', 'c', 'h', 'i', 'l', 'l', 'e', ' ', 'P', 'i', 'c', 'c', 'i', 'n', 'i'],
#  ['A',
#   'c',
#   'h',
#   'i',
#   'l',
#   'l',
#   'e',
#   ' ',
#   'S',
#   'o',
#   'u',
#   'c',
#   'h',
#   'a',
#   'r',
#   'd'],
#  ['A', 'c', 'h', 'i', 'm', ' ', 'H', 'i', 'l', 'l'],
#  ['A', 'd', 'a', ' ', 'S', 'm', 'i', 't', 'h'],
#  ['A',
#   'd',
#   'a',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   's',
#   ' ',
#   'B',
#   'u',
#   'b',
#   'e',
#   'n',
#   'k',
#   'o'],
#  ['A', 'd', 'a', 'm', ' ', 'C', 'o', 'm', 'm', 'e', 'n', 's'],
#  ['A', 'd', 'a', 'm', ' ', 'E', 'n', 'r', 'i', 'g', 'h', 't'],
#  ['A', 'd', 'a', 'm', ' ', 'F', 'o', 'o', 't', 'e'],
#  ['A', 'd', 'a', 'm', ' ', 'K', 'o', 'r', 'o', 'l'],
#  ['A', 'd', 'a', 'm', ' ', 'K', 'r', 'e', 'e', 'k'],
#  ['A',
#   'd',
#   'a',
#   'm',
#   ' ',
#   'K',
#   'r',
#   'o',
#   'l',
#   'i',
#   'k',
#   'i',
#   'e',
#   'w',
#   'i',
#   'c',
#   'z'],
#  ['A', 'd', 'a', 'm', ' ', 'K', 'r', 'z', 'e', 's', 'i', 'n', 's', 'k', 'i'],
#  ['A', 'd', 'a', 'm', ' ', 'L', 'i', 's', 'e', 'w', 's', 'k', 'i'],
#  ['A', 'd', 'a', 'm', ' ', 'M', 'a', 'l', 'y', 's', 'z'],
#  ['A', 'd', 'a', 'm', ' ', 'M', 'a', 'r', 'o', 's', 'i'],
#  ['A', 'd', 'a', 'm', ' ', 'P', 'a', 'p', ' ', 'E'],
#  ['A', 'd', 'a', 'm', ' ', 'P', 'i', 'n', 'e'],
#  ['A', 'd', 'a', 'm', ' ', 'R', 'o', 'b', 'a', 'k'],
#  ['A', 'd', 'a', 'm', ' ', 'R', 'o', 't', 'h', 'e', 'r', 'm', 'e', 'l'],
#  ['A', 'd', 'a', 'm', ' ', 'S', 'a', 'n', 'd', 'u', 'r', 's', 'k', 'i'],
#  ['A',
#   'd',
#   'a',
#   'm',
#   ' ',
#   'S',
#   'e',
#   'r',
#   'o',
#   'c',
#   'z',
#   'y',
#   'n',
#   's',
#   'k',
#   'i'],
#  ['A',
#   'd',
#   'a',
#   'm',
#   ' ',
#   'S',
#   'm',
#   'e',
#   'l',
#   'c',
#   'z',
#   'y',
#   'n',
#   's',
#   'k',
#   'i'],
#  ['A', 'd', 'a', 'm', ' ', 'T', 'o', 'm', 'a', 's', 'i', 'a', 'k'],
#  ['A',
#   'd',
#   'a',
#   'm',
#   ' ',
#   'V',
#   'a',
#   'n',
#   ' ',
#   'K',
#   'o',
#   'e',
#   'v',
#   'e',
#   'r',
#   'd',
#   'e',
#   'n'],
#  ['A', 'd', 'a', 'm', ' ', 'V', 'e', 'l', 'l', 'a'],
#  ['A', 'd', 'a', 'm', ' ', 'W', 'i', 'e', 'r', 'c', 'i', 'o', 'c', 'h'],
#  ['A', 'd', 'd', 'i', 's', ' ', 'A', 'b', 'e', 'b', 'e'],
#  ['A',
#   'd',
#   'e',
#   ' ',
#   'A',
#   'l',
#   'l',
#   'e',
#   'y',
#   'n',
#   'e',
#   ' ',
#   'F',
#   'o',
#   'r',
#   't',
#   'e'],
#  ['A',
#   'd',
#   'e',
#   'l',
#   'h',
#   'e',
#   'i',
#   'd',
#   ' ',
#   'B',
#   'a',
#   'r',
#   'b',
#   'a',
#   'r',
#   'a',
#   ' ',
#   'S',
#   'c',
#   'h',
#   'm',
#   'i',
#   'd'],
#  ['A',
#   'd',
#   'e',
#   'l',
#   'h',
#   'e',
#   'i',
#   'd',
#   ' ',
#   'R',
#   'o',
#   'b',
#   'b',
#   'i',
#   'a',
#   'n',
#   'i'],
#  ['A',
#   'd',
#   'e',
#   'l',
#   'i',
#   'n',
#   'd',
#   'e',
#   ' ',
#   'C',
#   'o',
#   'r',
#   'n',
#   'e',
#   'l',
#   'i',
#   's',
#   's',
#   'e',
#   'n'],
#  ['A',
#   'd',
#   'e',
#   'l',
#   'm',
#   'o',
#   ' ',
#   'B',
#   'u',
#   'l',
#   'g',
#   'a',
#   'r',
#   'e',
#   'l',
#   'l',
#   'i'],
#  ['A', 'd', 'e', 'm', ' ', 'B', 'e', 'r', 'e', 'k', 'e', 't'],
#  ['A',
#   'd',
#   'e',
#   'm',
#   'i',
#   'r',
#   ' ',
#   'R',
#   'o',
#   'q',
#   'u',
#   'e',
#   ' ',
#   'K',
#   'a',
#   'e',
#   'f',
#   'e',
#   'r'],
#  ['A', 'd', 'e', 'n', 'i', 'z', 'i', 'a', ' ', 'S', 'i', 'l', 'v', 'a'],
#  ['A', 'd', 'e', 's', 'i', 'o', ' ', 'L', 'o', 'm', 'b', 'a', 'r', 'd', 'o'],
#  ['A',
#   'd',
#   'h',
#   'e',
#   'm',
#   'a',
#   'r',
#   ' ',
#   'C',
#   'a',
#   'n',
#   'a',
#   'v',
#   'e',
#   's',
#   'i'],
#  ['A',
#   'd',
#   'h',
#   'e',
#   'm',
#   'a',
#   'r',
#   ' ',
#   'F',
#   'e',
#   'r',
#   'r',
#   'e',
#   'i',
#   'r',
#   'a',
#   ' ',
#   'D',
#   'a',
#   ' ',
#   'S',
#   'i',
#   'l',
#   'v',
#   'a'],
#  ['A', 'd', 'i', 'e', 'l', ' ', 'P', 'a', 'l', 'm', 'a'],
#  ['A', 'd', 'i', 'l', ' ', 'A', 't', 'a', 'n'],
#  ['A', 'd', 'i', 'l', ' ', 'C', 'a', 'n', 'd', 'e', 'm', 'i', 'r'],
#  ['A',
#   'd',
#   'i',
#   'l',
#   'b',
#   'e',
#   'k',
#   ' ',
#   'N',
#   'i',
#   'y',
#   'a',
#   'z',
#   'y',
#   'm',
#   'b',
#   'e',
#   't',
#   'o',
#   'v'],
#  ['A', 'd', 'l', 'a', 'n', ' ', 'V', 'a', 'r', 'a', 'e', 'v'],
#  ['A', 'd', 'm', 'i', 'r', ' ', 'S', 'm', 'a', 'j', 'i', 'c'],
#  ['A', 'd', 'n', 'e', ' ', 'S', 'o', 'n', 'd', 'r', 'a', 'l'],
#  ['A',
#   'd',
#   'o',
#   'l',
#   'f',
#   ' ',
#   'A',
#   'u',
#   'f',
#   'd',
#   'e',
#   'n',
#   'b',
#   'l',
#   'a',
#   't',
#   't',
#   'e',
#   'n'],
#  ['A',
#   'd',
#   'o',
#   'l',
#   'f',
#   ' ',
#   'D',
#   'i',
#   'r',
#   'k',
#   ' ',
#   'C',
#   '.',
#   ' ',
#   'V',
#   'a',
#   'n',
#   ' ',
#   'D',
#   'e',
#   'r',
#   ' ',
#   'V',
#   'o',
#   'o',
#   'r',
#   't',
#   ' ',
#   'V',
#   'a',
#   'n',
#   ' ',
#   'Z',
#   'i',
#   'j',
#   'p'],
#  ['A', 'd', 'o', 'l', 'f', ' ', 'D', 'u', 's', 'e', 'k'],
#  ['A', 'd', 'o', 'l', 'f', ' ', 'K', 'a', 'i', 'n', 'z'],
#  ['A', 'd', 'o', 'l', 'f', ' ', 'K', 'o', 'x', 'e', 'd', 'e', 'r'],
#  ['A', 'd', 'o', 'l', 'f', ' ', 'L', 'a', 'u', 'd', 'o', 'n'],
#  ['A', 'd', 'o', 'l', 'f', ' ', 'M', ' ', 'L', 'l', 'e', 'r'],
#  ['A', 'd', 'o', 'l', 'f', ' ', 'S', 'c', 'h', 'm', 'a', 'l'],
#  ['A', 'd', 'o', 'l', 'f', ' ', 'S', 'e', 'g', 'e', 'r'],
#  ['A', 'd', 'o', 'l', 'f', ' ', 'S', 'p', 'i', 'n', 'n', 'l', 'e', 'r'],
#  ['A',
#   'd',
#   'o',
#   'l',
#   'f',
#   ' ',
#   'S',
#   't',
#   'o',
#   'c',
#   'k',
#   'h',
#   'a',
#   'u',
#   's',
#   'e',
#   'n'],
#  ['A', 'd', 'o', 'l', 'f', ' ', 'W', 'a', 'g', 'n', 'e', 'r'],
#  ['A',
#   'd',
#   'o',
#   'l',
#   'f',
#   'i',
#   'n',
#   'a',
#   ' ',
#   'T',
#   'a',
#   'c',
#   'o',
#   'v',
#   'a',
#   ' ',
#   'T',
#   'k',
#   'a',
#   'c',
#   'i',
#   'k',
#   'o',
#   'v',
#   'a'],
#  ['A',
#   'd',
#   'o',
#   'l',
#   'f',
#   'o',
#   ' ',
#   'B',
#   'a',
#   'l',
#   'o',
#   'n',
#   'c',
#   'i',
#   'e',
#   'r',
#   'i'],
#  ['A',
#   'd',
#   'o',
#   'l',
#   'f',
#   'o',
#   ' ',
#   'C',
#   'o',
#   'n',
#   's',
#   'o',
#   'l',
#   'i',
#   'n',
#   'i'],
#  ['A', 'd', 'o', 'l', 'f', 'o', ' ', 'H', 'o', 'r', 't', 'a'],
#  ['A', 'd', 'o', 'l', 'f', 'o', ' ', 'T', 'u', 'n', 'e', 's', 'i'],
#  ['A',
#   'd',
#   'o',
#   'l',
#   'p',
#   'h',
#   'e',
#   ' ',
#   'G',
#   'o',
#   'e',
#   'm',
#   'a',
#   'e',
#   'r',
#   'e'],
#  ['A',
#   'd',
#   'o',
#   'l',
#   'p',
#   'h',
#   'e',
#   ' ',
#   'J',
#   'a',
#   'u',
#   'r',
#   'e',
#   'g',
#   'u',
#   'y'],
#  ['A',
#   'd',
#   'o',
#   'l',
#   'p',
#   'h',
#   'e',
#   ' ',
#   'M',
#   'e',
#   'n',
#   'g',
#   'o',
#   't',
#   't',
#   'i'],
#  ['A',
#   'd',
#   'o',
#   'l',
#   'p',
#   'h',
#   'e',
#   ' ',
#   'R',
#   'e',
#   'n',
#   ' ',
#   'B',
#   'o',
#   'u',
#   's',
#   'q',
#   'u',
#   'e',
#   't'],
#  ['A', 'd', 'o', 'l', 'p', 'h', 'e', ' ', 'R', 'e', 'y', 'm', 'o', 'n', 'd'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'a',
#   'n',
#   ' ',
#   'J',
#   'a',
#   'c',
#   'o',
#   'b',
#   'u',
#   's',
#   ' ',
#   'B',
#   'r',
#   'a',
#   's',
#   'p',
#   'e',
#   'n',
#   'n',
#   'i',
#   'n'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'a',
#   'n',
#   ' ',
#   'J',
#   'o',
#   'h',
#   'a',
#   'n',
#   ' ',
#   'L',
#   'o',
#   'u',
#   'i',
#   's',
#   ' ',
#   'K',
#   'a',
#   't',
#   't',
#   'e'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'a',
#   'n',
#   ' ',
#   'L',
#   'a',
#   'm',
#   'b',
#   'e',
#   'r',
#   't',
#   'u',
#   's',
#   ' ',
#   'J',
#   'o',
#   's',
#   'e',
#   'p',
#   'h',
#   ' ',
#   'M',
#   'a',
#   'a',
#   's'],
#  ['A', 'd', 'r', 'i', 'a', 'n', ' ', 'A', 'u', 'c', 'o', 'i', 'n'],
#  ['A', 'd', 'r', 'i', 'a', 'n', ' ', 'B', 'u', 'r', 'n', 's', 'i', 'd', 'e'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   ' ',
#   'C',
#   'a',
#   'l',
#   'e',
#   'r',
#   'o',
#   ' ',
#   'M',
#   'o',
#   'n',
#   'g',
#   'e',
#   'r'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   ' ',
#   'C',
#   'h',
#   'a',
#   'r',
#   'l',
#   'e',
#   's',
#   ' ',
#   'E',
#   'l',
#   'l',
#   'i',
#   's',
#   'o',
#   'n'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   ' ',
#   'D',
#   'a',
#   'v',
#   'i',
#   'd',
#   ' ',
#   'M',
#   'o',
#   'o',
#   'r',
#   'h',
#   'o',
#   'u',
#   's',
#   'e'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   ' ',
#   'E',
#   'd',
#   'w',
#   'a',
#   'r',
#   'd',
#   ' ',
#   'Z',
#   'i',
#   'e',
#   'l',
#   'i',
#   'n',
#   's',
#   'k',
#   'i'],
#  ['A', 'd', 'r', 'i', 'a', 'n', ' ', 'J', 'a', 'r', 'd', 'i', 'n', 'e'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   ' ',
#   'P',
#   'e',
#   't',
#   'e',
#   'r',
#   ' ',
#   'M',
#   'e',
#   't',
#   'c',
#   'a',
#   'l',
#   'f',
#   'e'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   ' ',
#   'P',
#   'h',
#   'i',
#   'l',
#   'i',
#   'p',
#   ' ',
#   'P',
#   'a',
#   'r',
#   'k',
#   'e',
#   'r'],
#  ['A', 'd', 'r', 'i', 'a', 'n', ' ', 'P', 'l', 'a', 'v', 's', 'i', 'c'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   'a',
#   ' ',
#   'A',
#   'p',
#   'a',
#   'r',
#   'e',
#   'c',
#   'i',
#   'd',
#   'a',
#   ' ',
#   'S',
#   'a',
#   'n',
#   't',
#   'o',
#   's'],
#  ['A', 'd', 'r', 'i', 'a', 'n', 'a', ' ', 'B', 'e', 'h', 'a', 'r'],
#  ['A', 'd', 'r', 'i', 'a', 'n', 'a', ' ', 'C', 'a', 'r', 'm', 'o', 'n', 'a'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   'a',
#   ' ',
#   'D',
#   'u',
#   'n',
#   'a',
#   'v',
#   's',
#   'k',
#   'a'],
#  ['A', 'd', 'r', 'i', 'a', 'n', 'a', ' ', 'P', 'i', 'n', 't', 'o'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   'a',
#   ' ',
#   'S',
#   'a',
#   'm',
#   'u',
#   'e',
#   'l',
#   ' ',
#   'R',
#   'a',
#   'm',
#   'o',
#   's'],
#  ['A', 'd', 'r', 'i', 'a', 'n', 'a', ' ', 'V', 'i', 's', 's', 'e', 'r'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   'o',
#   ' ',
#   'F',
#   'r',
#   'a',
#   's',
#   's',
#   'i',
#   'n',
#   'e',
#   'l',
#   'l',
#   'i'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   'u',
#   's',
#   ' ',
#   'C',
#   'o',
#   'r',
#   'n',
#   'e',
#   'l',
#   'i',
#   's',
#   ' ',
#   'T',
#   'h',
#   'e',
#   'e',
#   'u',
#   'w',
#   'e',
#   's'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   'u',
#   's',
#   ' ',
#   'E',
#   'g',
#   'b',
#   'e',
#   'r',
#   't',
#   'u',
#   's',
#   ' ',
#   'W',
#   'i',
#   'l',
#   'l',
#   'e',
#   'm',
#   ' ',
#   'D',
#   'e',
#   ' ',
#   'J',
#   'o',
#   'n',
#   'g'],
#  ['A',
#   'd',
#   'r',
#   'i',
#   'a',
#   'n',
#   'u',
#   's',
#   ' ',
#   'V',
#   'a',
#   'n',
#   ' ',
#   'M',
#   'e',
#   'r',
#   'r',
#   'i',
#   'e',
#   'n',
#   'b',
#   'o',
#   'e',
#   'r'],
#  ['A', 'd', 'r', 'i', 'e', 'n', ' ', 'H', 'a', 'r', 'd', 'y'],
#  ['A', 'd', 'r', 'i', 'e', 'n', ' ', 'R', 'o', 'm', 'm', 'e', 'l'],
#  ['A', 'e', 'i', ' ', 'Y', 'o', 'u', 'n', 'g', ' ', 'C', 'h', 'o', 'i'],
#  ['A',
#   'e',
#   'r',
#   'n',
#   'o',
#   'u',
#   't',
#   ' ',
#   'V',
#   'a',
#   'n',
#   ' ',
#   'L',
#   'e',
#   'n',
#   'n',
#   'e',
#   'p'],
#  ['A',
#   'f',
#   'a',
#   'n',
#   'a',
#   's',
#   'i',
#   'j',
#   's',
#   ' ',
#   'K',
#   'u',
#   'z',
#   'm',
#   'i',
#   'n',
#   's'],
#  ['A',
#   'f',
#   'f',
#   'o',
#   'n',
#   's',
#   'o',
#   ' ',
#   'A',
#   'z',
#   'e',
#   'v',
#   'e',
#   'd',
#   'o',
#   ' ',
#   'E',
#   'v',
#   'o',
#   'r',
#   'a'],
#  ['A',
#   'f',
#   'r',
#   'a',
#   'n',
#   'i',
#   'o',
#   ' ',
#   'A',
#   'n',
#   't',
#   'o',
#   'n',
#   'i',
#   'o',
#   ' ',
#   'D',
#   'a',
#   ' ',
#   'C',
#   'o',
#   's',
#   't',
#   'a'],
#  ['A', 'g', 'a', 't', 'a', ' ', 'W', 'r', 'o', 'b', 'e', 'l'],
#  ['A', 'g', 'a', 't', 'h', 'o', 'n', ' ', 'D', 'e', ' ', 'R', 'o', 'o', 's'],
#  ['A',
#   'g',
#   'e',
#   'e',
#   't',
#   'h',
#   ' ',
#   'B',
#   'o',
#   'o',
#   'm',
#   'g',
#   'a',
#   'a',
#   'r',
#   'd',
#   't'],
#  ['A', 'g', 'h', 'a', 's', 'i', ' ', 'M', 'a', 'm', 'm', 'a', 'd', 'o', 'v'],
#  ['A',
#   'g',
#   'n',
#   'e',
#   't',
#   'a',
#   ' ',
#   'A',
#   'n',
#   'd',
#   'e',
#   'r',
#   's',
#   's',
#   'o',
#   'n'],
#  ['A', 'g', 'n', 'e', 't', 'a', ' ', 'E', 'r', 'i', 'k', 's', 's', 'o', 'n'],
#  ['A',
#   'g',
#   'n',
#   'e',
#   't',
#   'a',
#   ' ',
#   'M',
#   ' ',
#   'R',
#   't',
#   'e',
#   'n',
#   's',
#   's',
#   'o',
#   'n'],
#  ['A', 'g', 'n', 'e', 't', 'e', ' ', 'C', 'a', 'r', 'l', 's', 'e', 'n'],
#  ['A',
#   'g',
#   'n',
#   'i',
#   'e',
#   's',
#   'z',
#   'k',
#   'a',
#   ' ',
#   'C',
#   'z',
#   'o',
#   'p',
#   'e',
#   'k'],
#  ['A',
#   'g',
#   'n',
#   'i',
#   'e',
#   's',
#   'z',
#   'k',
#   'a',
#   ' ',
#   'W',
#   'i',
#   'e',
#   's',
#   'z',
#   'c',
#   'z',
#   'e',
#   'k'],
#  ['A', 'g', 'o', ' ', 'A', 'u', 'g', 'u', 's', 't', ' ', 'N', 'e', 'o'],
#  ['A',
#   'g',
#   'o',
#   's',
#   't',
#   'i',
#   'n',
#   'o',
#   ' ',
#   'A',
#   'b',
#   'b',
#   'a',
#   'g',
#   'n',
#   'a',
#   'l',
#   'e'],
#  ['A',
#   'g',
#   'o',
#   's',
#   't',
#   'i',
#   'n',
#   'o',
#   ' ',
#   'S',
#   't',
#   'r',
#   'a',
#   'u',
#   'l',
#   'i',
#   'n',
#   'o'],
#  ['A', 'g', 'o', 't', 'a', ' ', 'B', 'u', 'j', 'd', 'o', 's', 'o'],
#  ['A',
#   'g',
#   'u',
#   'i',
#   'l',
#   'm',
#   'a',
#   'r',
#   ' ',
#   'O',
#   'l',
#   'i',
#   'v',
#   'e',
#   'i',
#   'r',
#   'a'],
#  ['A',
#   'g',
#   'u',
#   's',
#   't',
#   'i',
#   'n',
#   ' ',
#   'Z',
#   'a',
#   'r',
#   'a',
#   'g',
#   'o',
#   'z',
#   'a'],
#  ['A', 'g', 'u', 's', 't', 'i', 'n', 'a', ' ', 'G', 'a', 'r', 'c', 'i', 'a'],
#  ['A', 'h', 'm', 'a', 'd', ' ', 'B', 'a', 's', 'h', 'i', 'r'],
#  ['A', 'h', 'm', 'a', 'd', ' ', 'N', 'a', 's', 'i', 'r'],
#  ['A', 'h', 'm', 'a', 'd', ' ', 'R', 'i', 'a', 'z'],
#  ['A', 'h', 'm', 'e', 'd', ' ', 'I', 's', 'h', 't', 'i', 'a', 'q'],
#  ['A', 'h', 'm', 'e', 'd', ' ', 'M', 'a', 'n', 's', 'o', 'o', 'r'],
#  ['A', 'h', 'm', 'e', 'd', ' ', 'M', 'u', 's', 'h', 't', 'a', 'q'],
#  ['A', 'h', 'm', 'e', 'd', ' ', 'S', 'h', 'a', 'h', 'b', 'a', 'z'],
#  ['A', 'h', 'm', 'e', 'd', ' ', 'S', 'h', 'e', 'r', ' ', 'K', 'h', 'a', 'n'],
#  ['A', 'h', 'm', 'e', 't', ' ', 'A', 'y', 'i', 'k'],
#  ['A', 'h', 'm', 'e', 't', ' ', 'B', 'i', 'l', 'e', 'k'],
#  ['A', 'h', 'm', 'e', 't', ' ', 'K', 'i', 'r', 'e', ' ', 'I'],
#  ['A',
#   'h',
#   's',
#   'a',
#   'n',
#   ' ',
#   'M',
#   'o',
#   'h',
#   'o',
#   'm',
#   'e',
#   'd',
#   ' ',
#   'K',
#   'h',
#   'a',
#   'n'],
#  ['A', 'i', ' ', 'F', 'u', 'k', 'u', 'h', 'a', 'r', 'a'],
#  ['A', 'i', ' ', 'O', 't', 'o', 'm', 'o'],
#  ['A', 'i', ' ', 'S', 'h', 'i', 'b', 'a', 't', 'a'],
#  ['A', 'i', 'd', 'a', ' ', 'C', 'h', 'a', 'n', 'a', 'e', 'v', 'a'],
#  ['A', 'i', 'd', 'a', ' ', 'R', 'o', 'm', 'a', 'n'],
#  ['A',
#   'i',
#   'd',
#   'y',
#   'n',
#   ' ',
#   'A',
#   'l',
#   'i',
#   ' ',
#   'O',
#   'g',
#   'l',
#   'y',
#   ' ',
#   'I',
#   'b',
#   'r',
#   'a',
#   'g',
#   'i',
#   'm',
#   'o',
#   'v'],
#  ['A', 'i', 'd', 'y', 'n', ' ', 'S', 'm', 'a', 'g', 'u', 'l', 'o', 'v'],
#  ['A', 'i', 'g', 'a', 'r', 's', ' ', 'F', 'a', 'd', 'e', 'j', 'e', 'v', 's'],
#  ['A',
#   'i',
#   'k',
#   'a',
#   't',
#   'e',
#   'r',
#   'i',
#   'n',
#   'i',
#   ' ',
#   'O',
#   'i',
#   'k',
#   'o',
#   'n',
#   'o',
#   'm',
#   'o',
#   'p',
#   'o',
#   'u',
#   'l',
#   'o',
#   'u'],
#  ['A', 'i', 'k', 'o', ' ', 'O', 'n', 'o', 'z', 'a', 'w', 'a'],
#  ['A',
#   'i',
#   'l',
#   'e',
#   'e',
#   'n',
#   ' ',
#   'A',
#   'l',
#   'e',
#   't',
#   'h',
#   'a',
#   ' ',
#   'M',
#   'e',
#   'a',
#   'g',
#   'h',
#   'e',
#   'r'],
#  ['A', 'i', 'm', ' ', 'C', 'a', 's', 's', 'a', 'y', 'e', 't'],
#  ['A', 'i', 'm', ' ', 'H', 'a', 'e', 'g', 'e', 'm', 'a', 'n'],
#  ['A', 'i', 'm', 'i', 'l', 'i', 'a', ' ', 'T', 's', 'o', 'u', 'l', 'f', 'a'],
#  ['A', 'i', 'm', 'o', ' ', 'H', 'e', 'i', 'l', 'm', 'a', 'n', 'n'],
#  ['A', 'i', 'n', 'a', 'r', 's', ' ', 'K', 'o', 'v', 'a', 'l', 's'],
#  ['A',
#   'i',
#   'v',
#   'a',
#   'r',
#   ' ',
#   'L',
#   'a',
#   'z',
#   'd',
#   'e',
#   'n',
#   'i',
#   'e',
#   'k',
#   's'],
#  ['A', 'j', 'i', 't', 'p', 'a', 'l', ' ', 'S', 'i', 'n', 'g', 'h'],
#  ['A', 'k', 'a', 'k', 'i', ' ', 'C', 'h', 'a', 'c', 'h', 'u', 'a'],
#  ['A',
#   'k',
#   'a',
#   'k',
#   'i',
#   'o',
#   's',
#   ' ',
#   'K',
#   'a',
#   'k',
#   'i',
#   'a',
#   's',
#   'v',
#   'i',
#   'l',
#   'i',
#   's'],
#  ['A', 'k', 'e', ' ', 'A', 'n', 'd', 'e', 'r', 's', 's', 'o', 'n'],
#  ['A', 'k', 'e', ' ', 'B', 'e', 'r', 'g', 'q', 'v', 'i', 's', 't'],
#  ['A', 'k', 'e', ' ', 'S', 'e', 'y', 'f', 'f', 'a', 'r', 't', 'h'],
#  ['A', 'k', 'h', 't', 'a', 'r', ' ', 'G', 'u', 'l', 'r', 'e', 'z'],
#  ['A', 'k', 'h', 't', 'a', 'r', ' ', 'N', 'a', 'e', 'e', 'm'],
#  ['A', 'k', 'i', ' ', 'K', 'a', 'r', 'v', 'o', 'n', 'e', 'n'],
#  ['A', 'k', 'i', ' ', 'T', 'a', 'k', 'a', 'y', 'a', 'm', 'a'],
#  ['A', 'k', 'i', 'f', ' ', 'P', 'i', 'r', 'i', 'm'],
#  ['A', 'k', 'i', 'h', 'i', 'r', 'o', ' ', 'T', 'o', 'g', 'o'],
#  ['A', 'k', 'i', 'k', 'o', ' ', 'K', 'a', 'w', 'a', 's', 'e'],
#  ['A', 'k', 'i', 'n', 'o', 'b', 'u', ' ', 'O', 's', 'a', 'k', 'o'],
#  ['A',
#   'k',
#   'i',
#   'n',
#   'o',
#   'r',
#   'i',
#   ' ',
#   'N',
#   'a',
#   'k',
#   'a',
#   'y',
#   'a',
#   'm',
#   'a'],
#  ['A', 'k', 'i', 'o', ' ', 'K', 'a', 'm', 'i', 'n', 'a', 'g', 'a'],
#  ['A', 'k', 'i', 'o', ' ', 'S', 'o', 'd', 'a'],
#  ['A', 'k', 'i', 'r', 'a', ' ', 'K', 'o', 'n', 'o'],
#  ['A', 'k', 'i', 'r', 'a', ' ', 'K', 'u', 'd', 'o'],
#  ['A', 'k', 'i', 'r', 'a', ' ', 'K', 'u', 'r', 'o', 'i', 'w', 'a'],
#  ['A', 'k', 'i', 'r', 'a', ' ', 'O', 't', 'a'],
#  ['A', 'k', 'i', 't', 's', 'u', 'g', 'u', ' ', 'K', 'o', 'n', 'n', 'o'],
#  ['A', 'k', 's', 'a', 'n', 'a', ' ', 'M', 'i', 'a', 'n', 'k', 'o', 'v', 'a'],
#  ['A',
#   'k',
#   's',
#   'e',
#   'l',
#   ' ',
#   'B',
#   'o',
#   'n',
#   'd',
#   'e',
#   ' ',
#   'H',
#   'a',
#   'n',
#   's',
#   'e',
#   'n'],
#  ['A',
#   'k',
#   's',
#   'e',
#   'l',
#   ' ',
#   'L',
#   'u',
#   'n',
#   'd',
#   ' ',
#   'S',
#   'v',
#   'i',
#   'n',
#   'd',
#   'a',
#   'l'],
#  ['A', 'k', 's', 'e', 'l', ' ', 'S', ' ', 'R', 'e', 'n', 's', 'e', 'n'],
#  ['A',
#   'k',
#   'z',
#   'h',
#   'u',
#   'r',
#   'e',
#   'k',
#   ' ',
#   'T',
#   'a',
#   'n',
#   'a',
#   't',
#   'a',
#   'r',
#   'o',
#   'v'],
#  ['A', 'l', ' ', 'M', 'a', 'c', 'i', 'n', 'n', 'i', 's'],
#  ['A', 'l', 'a', 'd', 'a', 'r', ' ', 'G', 'e', 'r', 'e', 'v', 'i', 'c', 'h'],
#  ['A', 'l', 'a', 'i', 'n', ' ', 'B', 'e', 'r', 'n', 'a', 'r', 'd'],
#  ['A', 'l', 'a', 'i', 'n', ' ', 'B', 'o', 'n', 'd', 'u', 'e'],
#  ['A', 'l', 'a', 'i', 'n', ' ', 'C', 'a', 'l', 'm', 'a', 't'],
#  ['A', 'l', 'a', 'i', 'n', ' ', 'L', 'e', 'b', 'a', 's'],
#  ['A', 'l', 'a', 'i', 'n', ' ', 'M', 'i', 'm', 'o', 'u', 'n'],
#  ['A', 'l', 'a', 'i', 'n', ' ', 'M', 'o', 'i', 'n', 'e', 'a', 'u'],
#  ['A', 'l', 'a', 'i', 'n', ' ', 'M', 'o', 's', 'c', 'o', 'n', 'i'],
#  ['A', 'l', 'a', 'i', 'n', ' ', 'P', 'o', 'r', 't', 'e', 's'],
#  ['A', 'l', 'a', 'm', ' ', 'N', 'o', 'o', 'r'],
#  ['A', 'l', 'a', 'n', ' ', 'B', 'a', 'n', 'n', 'i', 's', 't', 'e', 'r'],
#  ['A',
#   'l',
#   'a',
#   'n',
#   ' ',
#   'B',
#   'l',
#   'a',
#   'i',
#   'r',
#   ' ',
#   'T',
#   'h',
#   'o',
#   'm',
#   'p',
#   's',
#   'o',
#   'n'],
#  ['A',
#   'l',
#   'a',
#   'n',
#   ' ',
#   'B',
#   'u',
#   'd',
#   'i',
#   ' ',
#   'K',
#   'u',
#   's',
#   'u',
#   'm',
#   'a'],
#  ['A', 'l', 'a', 'n', ' ', 'C', 'a', 'm', 'p', 'b', 'e', 'l', 'l'],
#  ['A', 'l', 'a', 'n', ' ', 'C', 'h', 'e', 's', 'n', 'e', 'y'],
#  ['A',
#   'l',
#   'a',
#   'n',
#   ' ',
#   'G',
#   'e',
#   'o',
#   'f',
#   'f',
#   'r',
#   'e',
#   'y',
#   ' ',
#   'G',
#   'r',
#   'o',
#   'v',
#   'e',
#   'r'],
#  ['A', 'l', 'a', 'n', ' ', 'G', 'r', 'e', 'g', 'o', 'v'],
#  ['A', 'l', 'a', 'n', ' ', 'H', '.', ' ', 'N', 'o', 'b', 'l', 'e'],
#  ['A',
#   'l',
#   'a',
#   'n',
#   ' ',
#   'J',
#   'o',
#   'h',
#   'n',
#   ' ',
#   'B',
#   'a',
#   'r',
#   'r',
#   'e',
#   't',
#   't'],
#  ['A',
#   'l',
#   'a',
#   'n',
#   ' ',
#   'K',
#   'e',
#   'm',
#   'p',
#   ' ',
#   'W',
#   'a',
#   'r',
#   'r',
#   'e',
#   'n'],
#  ['A',
#   'l',
#   'a',
#   'n',
#   ' ',
#   'L',
#   'i',
#   'o',
#   'n',
#   'e',
#   'l',
#   ' ',
#   'M',
#   'c',
#   ' ',
#   'I',
#   'n',
#   't',
#   'y',
#   'r',
#   'e'],
#  ['A', 'l', 'a', 'n', ' ', 'M', 'c', 'c', 'l', 'a', 't', 'c', 'h', 'e', 'y'],
#  ['A', 'l', 'a', 'n', ' ', 'M', 'i', 'n', 't', 'e', 'r'],
#  ['A', 'l', 'a', 'n', ' ', 'N', 'e', 'w', 't', 'o', 'n'],
#  ['A',
#   'l',
#   'a',
#   'n',
#   ' ',
#   'P',
#   'e',
#   't',
#   'e',
#   'r',
#   ' ',
#   'P',
#   'a',
#   's',
#   'c',
#   'o',
#   'e'],
#  ['A',
#   'l',
#   'a',
#   'n',
#   ' ',
#   'R',
#   'u',
#   'g',
#   'g',
#   'l',
#   'e',
#   's',
#   ' ',
#   'P',
#   'u',
#   'r',
#   'v',
#   'i',
#   's'],
#  ['A', 'l', 'a', 'n', ' ', 'T', 's', 'a', 'g', 'a', 'e', 'v'],
#  ['A',
#   'l',
#   'a',
#   'n',
#   ' ',
#   'W',
#   'h',
#   'a',
#   'r',
#   'm',
#   'b',
#   'y',
#   ' ',
#   'J',
#   'a',
#   'c',
#   'k',
#   's',
#   'o',
#   'n'],
#  ['A', 'l', 'a', 'n', 'n', 'a', ' ', 'K', 'r', 'a', 'u', 's'],
#  ['A', 'l', 'a', 's', 't', 'a', 'i', 'r', ' ', 'G', 'o', 'r', 'd', 'o', 'n'],
#  ['A',
#   'l',
#   'a',
#   's',
#   't',
#   'a',
#   'i',
#   'r',
#   ' ',
#   'H',
#   'e',
#   'a',
#   't',
#   'h',
#   'c',
#   'o',
#   't',
#   'e'],
#  ['A',
#   'l',
#   'a',
#   's',
#   't',
#   'a',
#   'i',
#   'r',
#   ' ',
#   'M',
#   'c',
#   'c',
#   'o',
#   'r',
#   'q',
#   'u',
#   'o',
#   'd',
#   'a',
#   'l',
#   'e'],
#  ['A', 'l', 'b', 'a', 'n', ' ', 'V', 'e', 'r', 'm', 'e', 's'],
#  ['A', 'l', 'b', 'a', 'n', 'o', ' ', 'P', 'e', 'r', 'a'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'A', 'm', 'r', 'h', 'e', 'i', 'n'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'A',
#   'r',
#   'n',
#   'h',
#   'e',
#   'i',
#   't',
#   'e',
#   'r'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'A', 'y', 'a', 't'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'A', 'z', 'a', 'r', 'y', 'a', 'n'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'B', 'a', 'c', 'h', 'm', 'a', 'n', 'n'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'B', 'o', 'g', 'e', 'n'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'B', 'o', 's', 'q', 'u', 'e', 't'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'B', 'r', 'e', 'h', 'm', 'e'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'C',
#   'a',
#   's',
#   't',
#   'e',
#   'l',
#   'e',
#   'y',
#   'n',
#   's'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'C',
#   'h',
#   'a',
#   'r',
#   'l',
#   'e',
#   's',
#   ' ',
#   'G',
#   'l',
#   'a',
#   'd',
#   's',
#   't',
#   'o',
#   'n',
#   'e'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'C', 'o', 'r', 'a', 'y'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'C', 'o', 'u', 'r', 'q', 'u', 'i', 'n'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'D',
#   '.',
#   ' ',
#   'V',
#   'a',
#   'n',
#   ' ',
#   'D',
#   'e',
#   ' ',
#   'P',
#   'l',
#   'a',
#   'n',
#   'c',
#   'k',
#   'e'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'D',
#   'e',
#   ' ',
#   'B',
#   'u',
#   'i',
#   'n',
#   'n',
#   'e'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'D',
#   'e',
#   ' ',
#   'R',
#   'o',
#   'o',
#   'c',
#   'k',
#   'e',
#   'r'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'D',
#   'e',
#   'b',
#   'o',
#   'r',
#   'g',
#   'i',
#   'e',
#   's'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'D',
#   'e',
#   'l',
#   'b',
#   'e',
#   'c',
#   'q',
#   'u',
#   'e'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'D',
#   'u',
#   'n',
#   'c',
#   'a',
#   'n',
#   's',
#   'o',
#   'n'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'D', 'u', 'p', 'o', 'u', 'y'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'D', 'u', 'r', 'a', 'n', 't'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'E',
#   'd',
#   'w',
#   'a',
#   'r',
#   'd',
#   ' ',
#   'B',
#   'e',
#   't',
#   't',
#   's'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'E',
#   'd',
#   'w',
#   'i',
#   'n',
#   ' ',
#   'H',
#   'i',
#   'l',
#   'l'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'F',
#   'r',
#   'i',
#   't',
#   's',
#   ' ',
#   'R',
#   'u',
#   'i',
#   'm',
#   's',
#   'c',
#   'h',
#   'o',
#   't',
#   'e',
#   'l'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'G', 'e', 'r', 'o', 'm', 'i', 'n', 'i'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'G', 'i', 'g', 'e', 'r'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'G', 'i', 'n', 'g', 'e', 'l', 'l'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'G', 'r', 'i', 's', 'a', 'r'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'H', 'a', 'e', 'p', 'e', 'r', 's'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'H',
#   'e',
#   'd',
#   'd',
#   'e',
#   'r',
#   'i',
#   'c',
#   'h'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'H',
#   'e',
#   'n',
#   'r',
#   'i',
#   ' ',
#   'C',
#   'a',
#   'n',
#   'e',
#   't'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'H',
#   'e',
#   'n',
#   'r',
#   'i',
#   'q',
#   'u',
#   'e',
#   'z'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'H', 'e', 'r', 's', 'o', 'y', 'e'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'H', 'i', 'l', 'l'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'I', 'r', 'e', 't', 'o', 'n'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'J', 'o', 'h', 'n', 's', 'o', 'n'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'J',
#   'o',
#   's',
#   'e',
#   'p',
#   'h',
#   ' ',
#   'K',
#   'e',
#   'm',
#   'p',
#   's',
#   't',
#   'e',
#   'r'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'K', 'u', 's', 'n', 'e', 't', 's'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'L', 'a', 'w', 'r', 'e', 'n', 'c', 'e'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'L',
#   'e',
#   'o',
#   'n',
#   'a',
#   'r',
#   'd',
#   ' ',
#   'O',
#   'l',
#   'd',
#   'm',
#   'a',
#   'n'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'M',
#   'a',
#   'c',
#   ' ',
#   'C',
#   'a',
#   'f',
#   'f',
#   'e',
#   'r',
#   'y'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'M', 'a', 'd', ' ', 'R', 'i', 'n'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'M', 'a', 'r', 't', 'i', 'n'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'M', 'a', 'y', 'a', 'u', 'd'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'M', 'i', 'c', 'h', 'a', 'n', 't'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'M', 'o', 'k', 'e', 'e', 'v'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'P', 'r', 'e', 'u', 's', 's'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'R',
#   'o',
#   'm',
#   ' ',
#   'O',
#   ' ',
#   'R',
#   'e',
#   'n',
#   'a',
#   'u',
#   'd'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'R', 'u', 's', 't'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'S', 'e', 'g', 'u', 'i', 'n'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'S', 'e', 'i', 'g', 'n', 'e', 'r'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'T', 'a', 'y', 'l', 'o', 'r'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'T', 'h', ' ', 'V', 'e', 'n', 'o', 'n'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'T', 'r', ' ', 'N', 'd', 'l', 'e'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'V', 'a', 'l', 't', 'i', 'n'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'V', 'o', 'o', 'r', 'n'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'W', 'e', 'i', 'l'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'W', 'h', 'i', 't', 'e'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'W',
#   'i',
#   'l',
#   'l',
#   'e',
#   'm',
#   ' ',
#   'T',
#   'r',
#   'e',
#   's',
#   'l',
#   'i',
#   'n',
#   'g'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'W', 'y', 'c', 'k', 'm', 'a', 'n', 's'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   ' ',
#   'X',
#   'a',
#   'v',
#   'i',
#   'e',
#   'r',
#   ' ',
#   'E',
#   'l',
#   'u',
#   'e',
#   'r',
#   'e'],
#  ['A', 'l', 'b', 'e', 'r', 't', ' ', 'Z', ' ', 'R', 'n', 'e', 'r'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'A',
#   'l',
#   'b',
#   'e',
#   'r',
#   'a',
#   'n',
#   'i',
#   ' ',
#   'S',
#   'a',
#   'm',
#   'a',
#   'r',
#   'i',
#   't',
#   'a',
#   'n',
#   'i'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'A',
#   'n',
#   'g',
#   'e',
#   'l',
#   'i',
#   'n',
#   'i'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'B',
#   'l',
#   'a',
#   'n',
#   'c',
#   'o',
#   ' ',
#   'F',
#   'e',
#   'r',
#   'n',
#   'a',
#   'n',
#   'd',
#   'e',
#   'z'],
#  ['A', 'l', 'b', 'e', 'r', 't', 'o', ' ', 'C', 'i', 's', 'o', 'l', 'l', 'a'],
#  ['A', 'l', 'b', 'e', 'r', 't', 'o', ' ', 'C', 'o', 'v', 'a'],
#  ['A', 'l', 'b', 'e', 'r', 't', 'o', ' ', 'D', 'e', 'm', 'i', 'd', 'd', 'i'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'G',
#   'h',
#   'i',
#   'b',
#   'e',
#   'l',
#   'l',
#   'i',
#   'n',
#   'i'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'G',
#   'h',
#   'i',
#   'l',
#   'a',
#   'r',
#   'd',
#   'i'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'G',
#   'i',
#   'l',
#   'a',
#   'r',
#   'd',
#   'i',
#   'n',
#   'o'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'H',
#   'e',
#   'r',
#   'n',
#   'a',
#   'n',
#   'd',
#   'e',
#   'z'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'J',
#   'u',
#   'a',
#   'n',
#   't',
#   'o',
#   'r',
#   'e',
#   'n',
#   'a'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'L',
#   'o',
#   'm',
#   'b',
#   'a',
#   'r',
#   'd',
#   'i'],
#  ['A', 'l', 'b', 'e', 'r', 't', 'o', ' ', 'M', 'a', 'r', 's', 'o', 'n'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'P',
#   'e',
#   'l',
#   'l',
#   'e',
#   'g',
#   'r',
#   'i',
#   'n',
#   'o'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'P',
#   'i',
#   'g',
#   'a',
#   'i',
#   'a',
#   'n',
#   'i'],
#  ['A', 'l', 'b', 'e', 'r', 't', 'o', ' ', 'R', 'a', 'd', 'i'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'R',
#   'a',
#   'm',
#   'o',
#   's',
#   ' ',
#   'S',
#   'e',
#   's',
#   'm',
#   'a'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'S',
#   'a',
#   'n',
#   't',
#   'i',
#   'a',
#   'g',
#   'o',
#   ' ',
#   'L',
#   'o',
#   'v',
#   'e',
#   'l',
#   'l'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'T',
#   'o',
#   'm',
#   'a',
#   's',
#   'i',
#   'n',
#   'a'],
#  ['A', 'l', 'b', 'e', 'r', 't', 'o', ' ', 'T', 'o', 'm', 'b', 'a'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'V',
#   'a',
#   'l',
#   'd',
#   'e',
#   's',
#   ' ',
#   'L',
#   'a',
#   'c',
#   'a',
#   'r',
#   'r',
#   'a'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'V',
#   'a',
#   'l',
#   'd',
#   'e',
#   'z',
#   ' ',
#   'R',
#   'a',
#   'm',
#   'o',
#   's'],
#  ['A', 'l', 'b', 'e', 'r', 't', 'o', ' ', 'W', 'i', 'n', 'k', 'l', 'e', 'r'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   's',
#   'o',
#   'n',
#   ' ',
#   'V',
#   'a',
#   'n',
#   ' ',
#   'Z',
#   'o',
#   ' ',
#   'P',
#   'o',
#   's',
#   't'],
#  ['A',
#   'l',
#   'b',
#   'i',
#   'n',
#   ' ',
#   'L',
#   'e',
#   'r',
#   'm',
#   'u',
#   's',
#   'i',
#   'a',
#   'u',
#   'x'],
#  ['A', 'l', 'b', 'i', 'n', ' ', 'V', 'i', 'd', 'o', 'v', 'i', 'c'],
#  ['A', 'l', 'd', 'a', 'i', 'r'],
#  ['A', 'l', 'd', 'o', ' ', 'A', 'u', 'r', 'e', 'g', 'g', 'i'],
#  ['A', 'l', 'd', 'o', ' ', 'D', 'e', 'z', 'i'],
#  ['A', 'l', 'd', 'o', ' ', 'E', 'm', 'i', 'n', 'e', 'n', 't', 'e'],
#  ['A', 'l', 'd', 'o', ' ', 'G', 'h', 'i', 'r', 'a'],
#  ['A', 'l', 'd', 'o', ' ', 'M', 'a', 's', 'c', 'i', 'o', 't', 't', 'a'],
#  ['A', 'l', 'd', 'o', ' ', 'M', 'o', 'n', 't', 'a', 'n', 'o'],
#  ['A', 'l', 'd', 'o', ' ', 'N', 'a', 'd', 'i'],
#  ['A', 'l', 'd', 'o', ' ', 'T', 'a', 'r', 'l', 'a', 'o'],
#  ['A',
#   'l',
#   'd',
#   'o',
#   'n',
#   'a',
#   ' ',
#   'C',
#   'h',
#   'e',
#   's',
#   'a',
#   'i',
#   't',
#   'i',
#   't',
#   'e',
#   ' ',
#   'N',
#   'e',
#   'n',
#   'e',
#   'n',
#   'e',
#   'n',
#   'e'],
#  ['A',
#   'l',
#   'e',
#   'c',
#   ' ',
#   'B',
#   'r',
#   'a',
#   's',
#   's',
#   'e',
#   'y',
#   ' ',
#   'J',
#   'o',
#   'n',
#   'a',
#   't',
#   'h',
#   'a',
#   'n',
#   ' ',
#   'S',
#   'c',
#   'o',
#   't',
#   't'],
#  ['A', 'l', 'e', 'e', 'n', ' ', 'B', 'a', 'i', 'l', 'e', 'y'],
#  ['A',
#   'l',
#   'e',
#   'j',
#   'a',
#   'n',
#   'd',
#   'r',
#   'a',
#   ' ',
#   'D',
#   'e',
#   ' ',
#   'L',
#   'a',
#   ' ',
#   'G',
#   'u',
#   'e',
#   'r',
#   'r',
#   'a'],
#  ['A', 'l', 'e', 'j', 'a', 'n', 'd', 'r', 'a', ' ', 'G', 'u', 'l', 'l', 'a'],
#  ['A',
#   'l',
#   'e',
#   'j',
#   'a',
#   'n',
#   'd',
#   'r',
#   'a',
#   ' ',
#   'O',
#   'r',
#   'o',
#   'z',
#   'c',
#   'o',
#   ' ',
#   'L',
#   'o',
#   'z',
#   'a'],
#  ['A',
#   'l',
#   'e',
#   'j',
#   'a',
#   'n',
#   'd',
#   'r',
#   'i',
#   'n',
#   'a',
#   ' ',
#   'L',
#   'u',
#   'i',
#   's'],
#  ['A',
#   'l',
#   'e',
#   'j',
#   'a',
#   'n',
#   'd',
#   'r',
#   'o',
#   ' ',
#   'A',
#   'r',
#   'i',
#   'e',
#   'l',
#   ' ',
#   'M',
#   'o',
#   'n',
#   't',
#   'e',
#   'c',
#   'c',
#   'h',
#   'i',
#   'a'],
#  ['A',
#   'l',
#   'e',
#   'j',
#   'a',
#   'n',
#   'd',
#   'r',
#   'o',
#   ' ',
#   'C',
#   'a',
#   's',
#   'a',
#   'n',
#   'a',
#   's',
#   ' ',
#   'R',
#   'a',
#   'm',
#   'i',
#   'r',
#   'e',
#   'z'],
#  ['A', 'l', 'e', 'j', 'a', 'n', 'd', 'r', 'o', ' ', 'D', 'i', 'z'],
#  ['A',
#   'l',
#   'e',
#   'j',
#   'a',
#   'n',
#   'd',
#   'r',
#   'o',
#   ' ',
#   'P',
#   'u',
#   'e',
#   'r',
#   't',
#   'o',
#   ' ',
#   'D',
#   'i',
#   'a',
#   'z'],
#  ['A',
#   'l',
#   'e',
#   'j',
#   'a',
#   'n',
#   'd',
#   'r',
#   'o',
#   ' ',
#   'U',
#   'r',
#   'g',
#   'e',
#   'l',
#   'l',
#   'e',
#   's',
#   ' ',
#   'G',
#   'u',
#   'i',
#   'b',
#   'o',
#   't'],
#  ['A', 'l', 'e', 'k', 's', 'a', ' ', 'S', 'a', 'p', 'o', 'n', 'j', 'i', 'c'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'a',
#   'r',
#   ' ',
#   'A',
#   't',
#   'a',
#   'n',
#   'a',
#   's',
#   'k',
#   'o',
#   'v',
#   'i',
#   'c'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'a',
#   'r',
#   ' ',
#   'C',
#   'i',
#   'r',
#   'i',
#   'c'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'a',
#   'r',
#   ' ',
#   'D',
#   'j',
#   'o',
#   'r',
#   'd',
#   'j',
#   'e',
#   'v',
#   'i',
#   'c'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'a',
#   'r',
#   ' ',
#   'K',
#   'o',
#   'z',
#   'l',
#   'i',
#   'n',
#   'a'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'a',
#   'r',
#   ' ',
#   'K',
#   'r',
#   'a',
#   'i',
#   't',
#   'c',
#   'h',
#   'e',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'a',
#   'r',
#   ' ',
#   'K',
#   'r',
#   'i',
#   's',
#   't',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'a',
#   'r',
#   ' ',
#   'P',
#   'e',
#   't',
#   'r',
#   'o',
#   'v',
#   'i',
#   'c'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'a',
#   'r',
#   ' ',
#   'S',
#   'a',
#   'p',
#   'i',
#   'c'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'a',
#   'r',
#   ' ',
#   'S',
#   'o',
#   's',
#   't',
#   'a',
#   'r'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'e',
#   'r',
#   ' ',
#   'C',
#   'h',
#   'i',
#   'r',
#   'c',
#   'h',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'e',
#   'r',
#   ' ',
#   'C',
#   'i',
#   'c',
#   'h',
#   'o',
#   'n'],
#  ['A', 'l', 'e', 'k', 's', 'a', 'n', 'd', 'e', 'r', ' ', 'K', 'l', 'a', 'k'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'e',
#   'r',
#   ' ',
#   'P',
#   'e',
#   't',
#   'r',
#   'o',
#   'f',
#   'f'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'e',
#   'r',
#   ' ',
#   'R',
#   'o',
#   'm',
#   'a',
#   'n',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'e',
#   'r',
#   ' ',
#   'S',
#   '.',
#   ' ',
#   'M',
#   'a',
#   'l',
#   'e',
#   'c',
#   'k',
#   'i'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'e',
#   'r',
#   ' ',
#   'V',
#   'a',
#   'r',
#   'b',
#   'a',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'A',
#   'b',
#   'u',
#   's',
#   'h',
#   'a',
#   'k',
#   'h',
#   'm',
#   'e',
#   't',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'A',
#   'k',
#   's',
#   'i',
#   'n',
#   'i',
#   'n'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'A',
#   'l',
#   'm',
#   'e',
#   't',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'A',
#   'n',
#   'p',
#   'i',
#   'l',
#   'o',
#   'g',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'A',
#   'n',
#   'u',
#   'f',
#   'r',
#   'i',
#   'y',
#   'e',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'B',
#   'a',
#   'r',
#   'y',
#   's',
#   'h',
#   'n',
#   'i',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'B',
#   'a',
#   't',
#   'i',
#   'u',
#   'k'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'B',
#   'e',
#   'l',
#   'i',
#   'a',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'B',
#   'e',
#   'l',
#   'o',
#   's',
#   't',
#   'e',
#   'n',
#   'n',
#   'y',
#   'i'],
#  ['A', 'l', 'e', 'k', 's', 'a', 'n', 'd', 'r', ' ', 'B', 'e', 'l', 'o', 'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'B',
#   'e',
#   'r',
#   'k',
#   'u',
#   't',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'B',
#   'l',
#   'i',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'B',
#   'o',
#   'l',
#   'o',
#   's',
#   'h',
#   'e',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'B',
#   'o',
#   'r',
#   'o',
#   'd',
#   'y',
#   'u',
#   'k'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'B',
#   'u',
#   'd',
#   'n',
#   'i',
#   'k',
#   'o',
#   'v'],
#  ['A', 'l', 'e', 'k', 's', 'a', 'n', 'd', 'r', ' ', 'C', 'h', 'a', 'e', 'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'C',
#   'h',
#   'i',
#   'v',
#   'a',
#   'd',
#   'z',
#   'e'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'C',
#   'h',
#   'u',
#   'c',
#   'h',
#   'e',
#   'l',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'D',
#   'e',
#   'g',
#   't',
#   'y',
#   'a',
#   'r',
#   'e',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'D',
#   'i',
#   't',
#   'y',
#   'a',
#   't',
#   'i',
#   'n'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'D',
#   'o',
#   'l',
#   'g',
#   'u',
#   's',
#   'h',
#   'i',
#   'n'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'D',
#   'r',
#   'e',
#   'v',
#   'a',
#   'l'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'D',
#   'u',
#   'm',
#   'c',
#   'h',
#   'e',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'E',
#   'r',
#   'm',
#   'i',
#   'l',
#   'o',
#   'v'],
#  ['A', 'l', 'e', 'k', 's', 'a', 'n', 'd', 'r', ' ', 'G', 'a', 'z', 'o', 'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'G',
#   'e',
#   'r',
#   'a',
#   's',
#   'i',
#   'm',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'G',
#   'o',
#   'l',
#   'i',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'G',
#   'o',
#   'n',
#   'c',
#   'h',
#   'a',
#   'r',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'G',
#   'o',
#   'r',
#   'e',
#   'l',
#   'i',
#   'k'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'G',
#   'o',
#   'r',
#   's',
#   'h',
#   'k',
#   'o',
#   'v'],
#  ['A', 'l', 'e', 'k', 's', 'a', 'n', 'd', 'r', ' ', 'G', 'u', 's', 'e', 'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'I',
#   'v',
#   'a',
#   'n',
#   'i',
#   't',
#   's',
#   'k',
#   'y'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'I',
#   'v',
#   'a',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'a',
#   'b',
#   'a',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'a',
#   'r',
#   'e',
#   'l',
#   'i',
#   'n'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'a',
#   'r',
#   's',
#   'h',
#   'a',
#   'k',
#   'e',
#   'v',
#   'i',
#   'c',
#   'h'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'a',
#   'z',
#   'a',
#   'k',
#   'e',
#   'v',
#   'i',
#   'c'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'e',
#   'd',
#   'y',
#   'a',
#   'r',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'i',
#   'r',
#   'i',
#   'c',
#   'h',
#   'e',
#   'n',
#   'k',
#   'o'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'l',
#   'e',
#   'p',
#   'i',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'o',
#   'l',
#   'c',
#   'h',
#   'i',
#   'n',
#   's',
#   'k',
#   'y'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'o',
#   'l',
#   'o',
#   't',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'o',
#   'r',
#   'n',
#   'e',
#   'l',
#   'y',
#   'u',
#   'k'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'o',
#   's',
#   'e',
#   'n',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'o',
#   's',
#   'h',
#   'k',
#   'i',
#   'n'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'o',
#   'z',
#   'h',
#   'e',
#   'r',
#   'n',
#   'i',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'u',
#   'l',
#   'a',
#   'g',
#   'i',
#   'n'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'K',
#   'u',
#   'r',
#   'y',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'L',
#   'u',
#   'k',
#   'y',
#   'a',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'a',
#   'k',
#   'a',
#   'r',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'a',
#   'l',
#   'e',
#   'e',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'a',
#   'l',
#   't',
#   's',
#   'e',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'a',
#   'n',
#   't',
#   's',
#   'e',
#   'v',
#   'i',
#   'c',
#   'h'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'a',
#   'r',
#   'c',
#   'h',
#   'e',
#   'n',
#   'k',
#   'o'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'a',
#   'r',
#   't',
#   'i',
#   's',
#   'h',
#   'k',
#   'i',
#   'n'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'e',
#   'd',
#   'v',
#   'e',
#   'd'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'e',
#   'l',
#   'e',
#   'n',
#   't',
#   'i',
#   'e',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'i',
#   'a',
#   's',
#   'n',
#   'i',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'i',
#   'n',
#   'a',
#   'e',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'i',
#   'r',
#   'o',
#   's',
#   'h',
#   'n',
#   'i',
#   'c',
#   'h',
#   'e',
#   'n',
#   'k',
#   'o'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'o',
#   'g',
#   'i',
#   'l',
#   'n',
#   'y'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'o',
#   'i',
#   's',
#   'e',
#   'e',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'o',
#   't',
#   'u',
#   'z',
#   'e',
#   'n',
#   'k',
#   'o'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'o',
#   'z',
#   'h',
#   'a',
#   'e',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'M',
#   'u',
#   'z',
#   'y',
#   'c',
#   'h',
#   'e',
#   'n',
#   'k',
#   'o'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'N',
#   'i',
#   'k',
#   'o',
#   'l',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'P',
#   'a',
#   'c',
#   'h',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'P',
#   'a',
#   'n',
#   'f',
#   'i',
#   'l',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'P',
#   'a',
#   'v',
#   'l',
#   'o',
#   'v',
#   's',
#   'k',
#   'y'],
#  ['A', 'l', 'e', 'k', 's', 'a', 'n', 'd', 'r', ' ', 'P', 'e', 'r', 'o', 'v'],
#  ['A', 'l', 'e', 'k', 's', 'a', 'n', 'd', 'r', ' ', 'P', 'e', 'r', 'v', 'i'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'P',
#   'e',
#   't',
#   'r',
#   'o',
#   'v'],
#  ['A', 'l', 'e', 'k', 's', 'a', 'n', 'd', 'r', ' ', 'P', 'o', 'p', 'o', 'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'P',
#   'o',
#   'r',
#   't',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'P',
#   'r',
#   'i',
#   'v',
#   'a',
#   'l',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'P',
#   'r',
#   'o',
#   'k',
#   'h',
#   'o',
#   'r',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'P',
#   'r',
#   'o',
#   'k',
#   'o',
#   'p',
#   'e',
#   'n',
#   'k',
#   'o'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'P',
#   'u',
#   'c',
#   'h',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'R',
#   'a',
#   'g',
#   'u',
#   'l',
#   'i',
#   'n'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'R',
#   'e',
#   'z',
#   'a',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'R',
#   'o',
#   'd',
#   'i',
#   'o',
#   'n',
#   'o',
#   'v'],
#  ['A', 'l', 'e', 'k', 's', 'a', 'n', 'd', 'r', ' ', 'R', 'o', 'g', 'o', 'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'R',
#   'y',
#   'm',
#   'a',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'S',
#   'a',
#   'l',
#   'n',
#   'i',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'S',
#   'a',
#   'p',
#   'r',
#   'y',
#   'k',
#   'i',
#   'n'],
#  ['A', 'l', 'e', 'k', 's', 'a', 'n', 'd', 'r', ' ', 'S', 'a', 'v', 'i', 'n'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'S',
#   'h',
#   'a',
#   'p',
#   'a',
#   'r',
#   'e',
#   'n',
#   'k',
#   'o'],
#  ['A',
#   'l',
#   'e',
#   'k',
#   's',
#   'a',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'S',
#   'h',
#   'i',
#   'd',
#   'l',
#   'o',
#   'v',
#   's',
#   'k',
# ...
#   'm',
#   'u',
#   'k',
#   'h',
#   'a',
#   'm',
#   'e',
#   'd',
#   'o',
#   'v'],
#  ['A', 'm', ' ', 'D', ' ', 'T', 'h', 'u', 'b', 'e'],
#  ['A', 'm', 'a', 'd', 'o', ' ', 'A', 'z', 'a', 'r'],
#  ['A',
#   'm',
#   'a',
#   'l',
#   'i',
#   'a',
#   ' ',
#   'S',
#   't',
#   'e',
#   'r',
#   'b',
#   'i',
#   'n',
#   's',
#   'z',
#   'k',
#   'y'],
#  ['A', 'm', 'a', 'n', 'd', 'a', ' ', 'D', 'o', 'm', 'a', 'n'],
#  ['A', 'm', 'a', 'n', 'd', 'a', ' ', 'K', 'u', 'r', 't', 'o', 'v', 'i', 'c'],
#  ['A', 'm', 'a', 'n', 'd', 'a', ' ', 'O', 'v', 'e', 'r', 'l', 'a', 'n', 'd'],
#  ['A', 'm', 'a', 'r', 'a', 'l'],
#  ['A', 'm', 'a', 'r', 'i', 'l', 'y', 's', ' ', 'S', 'a', 'v', 'o', 'n'],
#  ['A', 'm', 'a', 'u', 'r', 'i', ' ', 'R', 'i', 'b', 'e', 'i', 'r', 'o'],
#  ['A', 'm', 'a', 'u', 'r', 'y', ' ', 'L', 'e', 'v', 'e', 'a', 'u', 'x'],
#  ['A', 'm', 'a', 'u', 'r', 'y', 's', ' ', 'P', 'e', 'r', 'e', 'z'],
#  ['A', 'm', 'b', 'e', 'r', ' ', 'B', 'r', 'a', 'd', 'l', 'e', 'y'],
#  ['A', 'm', 'b', 'r', 'o', 'g', 'i', 'o', ' ', 'L', 'e', 'v', 'a', 't', 'i'],
#  ['A',
#   'm',
#   'b',
#   'r',
#   'o',
#   's',
#   'i',
#   ' ',
#   'H',
#   'o',
#   'f',
#   'f',
#   'm',
#   'a',
#   'n',
#   'n'],
#  ['A',
#   'm',
#   'b',
#   'r',
#   'u',
#   's',
#   'e',
#   ' ',
#   'V',
#   'a',
#   'n',
#   'z',
#   'e',
#   'k',
#   'i',
#   'n'],
#  ['A', 'm', 'e', 'd', 'e', ' ', 'F', 'o', 'u', 'r', 'n', 'i', 'e', 'r'],
#  ['A', 'm', 'e', 'd', 'e', 'o', ' ', 'A', 'm', 'b', 'r', 'o', 'n'],
#  ['A', 'm', 'e', 'd', 'e', 'o', ' ', 'P', 'o', 'm', 'i', 'l', 'i', 'o'],
#  ['A',
#   'm',
#   'e',
#   'l',
#   'i',
#   'a',
#   ' ',
#   'P',
#   'i',
#   'c',
#   'c',
#   'i',
#   'n',
#   'i',
#   'n',
#   'i'],
#  ['A',
#   'm',
#   'e',
#   'l',
#   'i',
#   'e',
#   ' ',
#   'G',
#   'o',
#   'u',
#   'l',
#   'e',
#   't',
#   ' ',
#   'N',
#   'a',
#   'd',
#   'o',
#   'n'],
#  ['A', 'm', 'e', 'l', 'i', 'e', ' ', 'K', 'o', 'b', 'e', 'r'],
#  ['A', 'm', 'e', 'l', 'i', 'e', ' ', 'L', 'u', 'x'],
#  ['A', 'm', 'e', 'l', 'i', 'e', ' ', 'M', 'a', 'u', 'r', 'e', 's', 'm', 'o'],
#  ['A',
#   'm',
#   'i',
#   'r',
#   ' ',
#   'C',
#   'h',
#   'a',
#   'n',
#   'd',
#   ' ',
#   'K',
#   'u',
#   'm',
#   'a',
#   'r'],
#  ['A', 'm', 'i', 'r', ' ', 'K', 'h', 'a', 'n'],
#  ['A',
#   'm',
#   'i',
#   'r',
#   ' ',
#   'R',
#   'e',
#   'z',
#   'a',
#   ' ',
#   'K',
#   'h',
#   'a',
#   'd',
#   'e',
#   'm',
#   ' ',
#   'A',
#   'z',
#   'g',
#   'h',
#   'a',
#   'd',
#   'i'],
#  ['A',
#   'm',
#   'i',
#   'r',
#   'a',
#   'n',
#   ' ',
#   'K',
#   'a',
#   'r',
#   'n',
#   't',
#   'a',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'm',
#   'i',
#   'r',
#   'a',
#   'n',
#   ' ',
#   'T',
#   'o',
#   't',
#   'i',
#   'k',
#   'a',
#   's',
#   'h',
#   'v',
#   'i',
#   'l',
#   'i'],
#  ['A',
#   'm',
#   'i',
#   't',
#   ' ',
#   'S',
#   'i',
#   'n',
#   'g',
#   'h',
#   ' ',
#   'B',
#   'a',
#   'k',
#   's',
#   'h',
#   'i'],
#  ['A', 'm', 'o', 's', ' ', 'D', 'e', ' ', 'K', 'a', 'c', 'h', 'e'],
#  ['A',
#   'm',
#   'o',
#   's',
#   ' ',
#   'K',
#   'i',
#   'p',
#   'w',
#   'a',
#   'b',
#   'o',
#   'k',
#   ' ',
#   'B',
#   'i',
#   'w',
#   'o',
#   't',
#   't'],
#  ['A', 'm', 'y', ' ', 'C', '.', ' ', 'J', 'a', 'g', 'g', 'e', 'r'],
#  ['A',
#   'm',
#   'y',
#   ' ',
#   'C',
#   'a',
#   't',
#   'h',
#   'e',
#   'r',
#   'i',
#   'n',
#   'e',
#   ' ',
#   'D',
#   'e',
#   ' ',
#   'B',
#   'a',
#   'r',
#   'y'],
#  ['A', 'm', 'y', ' ', 'H', 'e', 't', 'z', 'e', 'l'],
#  ['A', 'm', 'y', ' ', 'N', 'i', 'x', 'o', 'n'],
#  ['A', 'm', 'y', ' ', 'R', 'o', 'd', 'r', 'i', 'g', 'u', 'e', 'z'],
#  ['A',
#   'n',
#   'a',
#   ' ',
#   'B',
#   'e',
#   'a',
#   't',
#   'r',
#   'i',
#   'z',
#   ' ',
#   'M',
#   'o',
#   's',
#   'e',
#   'r'],
#  ['A', 'n', 'a', ' ', 'D', 'o', 'k', 'i', 'c'],
#  ['A',
#   'n',
#   'a',
#   ' ',
#   'F',
#   'i',
#   'd',
#   'e',
#   'l',
#   'i',
#   'a',
#   ' ',
#   'Q',
#   'u',
#   'i',
#   'r',
#   'o',
#   't'],
#  ['A',
#   'n',
#   'a',
#   ' ',
#   'F',
#   'l',
#   'a',
#   'v',
#   'i',
#   'a',
#   ' ',
#   'S',
#   'a',
#   'n',
#   'g',
#   'l',
#   'a',
#   'r',
#   'd'],
#  ['A', 'n', 'a', ' ', 'G', 'a', 'm', 'b', 'e', 'r', 'o'],
#  ['A', 'n', 'a', ' ', 'G', 'u', 'e', 'v', 'a', 'r', 'a'],
#  ['A',
#   'n',
#   'a',
#   ' ',
#   'I',
#   'b',
#   'i',
#   's',
#   ' ',
#   'F',
#   'e',
#   'r',
#   'n',
#   'a',
#   'n',
#   'd',
#   'e',
#   'z'],
#  ['A',
#   'n',
#   'a',
#   ' ',
#   'M',
#   'a',
#   'r',
#   'g',
#   'a',
#   'r',
#   'i',
#   't',
#   'a',
#   ' ',
#   'A',
#   'l',
#   'v',
#   'a',
#   'r',
#   'e',
#   's'],
#  ['A',
#   'n',
#   'a',
#   ' ',
#   'P',
#   'a',
#   'u',
#   'l',
#   'a',
#   ' ',
#   'C',
#   'o',
#   'n',
#   'n',
#   'e',
#   'l',
#   'l',
#   'y'],
#  ['A', 'n', 'a', ' ', 'R', 'a', 'd', 'o', 'v', 'i', 'c'],
#  ['A', 'n', 'a', ' ', 'T', 'i', 't', 'l', 'i', 'c'],
#  ['A',
#   'n',
#   'a',
#   's',
#   't',
#   'a',
#   's',
#   'i',
#   'a',
#   ' ',
#   'D',
#   'a',
#   'v',
#   'y',
#   'd',
#   'o',
#   'v',
#   'a'],
#  ['A',
#   'n',
#   'a',
#   's',
#   't',
#   'a',
#   's',
#   'i',
#   'a',
#   ' ',
#   'E',
#   'r',
#   'm',
#   'a',
#   'k',
#   'o',
#   'v',
#   'a'],
#  ['A',
#   'n',
#   'a',
#   's',
#   't',
#   'a',
#   's',
#   'i',
#   'a',
#   ' ',
#   'G',
#   'r',
#   'i',
#   's',
#   'h',
#   'i',
#   'n',
#   'a'],
#  ['A',
#   'n',
#   'a',
#   's',
#   't',
#   'a',
#   's',
#   'i',
#   'a',
#   ' ',
#   'K',
#   'a',
#   'p',
#   'a',
#   'c',
#   'h',
#   'i',
#   'n',
#   's',
#   'k',
#   'a',
#   'y',
#   'a'],
#  ['A',
#   'n',
#   'a',
#   's',
#   't',
#   'a',
#   's',
#   'i',
#   'a',
#   ' ',
#   'K',
#   'e',
#   'l',
#   'e',
#   's',
#   'i',
#   'd',
#   'o',
#   'u'],
#  ['A',
#   'n',
#   'a',
#   's',
#   't',
#   'a',
#   's',
#   'i',
#   'a',
#   ' ',
#   'P',
#   'o',
#   'z',
#   'd',
#   'n',
#   'y',
#   'a',
#   'k',
#   'o',
#   'v',
#   'a'],
#  ['A',
#   'n',
#   'a',
#   's',
#   't',
#   'a',
#   's',
#   'i',
#   'i',
#   'a',
#   ' ',
#   'K',
#   'o',
#   'z',
#   'h',
#   'e',
#   'n',
#   'k',
#   'o',
#   'v',
#   'a'],
#  ['A',
#   'n',
#   'a',
#   's',
#   't',
#   'a',
#   's',
#   'i',
#   'y',
#   'a',
#   ' ',
#   'B',
#   'o',
#   'r',
#   'o',
#   'd',
#   'i',
#   'n',
#   'a'],
#  ['A',
#   'n',
#   'a',
#   's',
#   't',
#   'a',
#   's',
#   's',
#   'i',
#   'o',
#   's',
#   ' ',
#   'B',
#   'o',
#   'u',
#   'd',
#   'o',
#   'u',
#   'r',
#   'i',
#   's'],
#  ['A',
#   'n',
#   'a',
#   's',
#   't',
#   'a',
#   's',
#   's',
#   'i',
#   'o',
#   's',
#   ' ',
#   'G',
#   'a',
#   'v',
#   'r',
#   'i',
#   'l',
#   'i',
#   's'],
#  ['A',
#   'n',
#   'a',
#   's',
#   't',
#   'a',
#   'z',
#   'i',
#   'a',
#   ' ',
#   'K',
#   'u',
#   'z',
#   'm',
#   'i',
#   'n',
#   'a'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'A', 'k', 'i', 'm', 'o', 'v'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'A', 'l', 'b', 'u', 'l'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'A',
#   's',
#   'r',
#   'a',
#   'b',
#   'a',
#   'e',
#   'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'B',
#   'a',
#   's',
#   'h',
#   'a',
#   's',
#   'h',
#   'k',
#   'i',
#   'n'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'B',
#   'e',
#   'l',
#   'o',
#   'g',
#   'l',
#   'a',
#   'z',
#   'o',
#   'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'B',
#   'o',
#   'g',
#   'd',
#   'a',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'B',
#   'o',
#   'n',
#   'd',
#   'a',
#   'r',
#   'c',
#   'h',
#   'u',
#   'k'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'B', 'u', 'l', 'a', 'k', 'o', 'v'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'B', 'y', 'k', 'o', 'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'C',
#   'h',
#   'u',
#   'k',
#   'a',
#   'n',
#   'o',
#   'v'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'C', 'i', 'r', 'i', 'c', 'u'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'D',
#   'e',
#   'm',
#   'i',
#   't',
#   'k',
#   'o',
#   'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'F',
#   'e',
#   'd',
#   'y',
#   'u',
#   'k',
#   'i',
#   'n'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'F', 'i', 'r', 's', 'o', 'v'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'G', 'r', 'i', 's', 'h', 'i', 'n'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'I', 'l', 'y', 'i', 'n'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'I', 'o', 'n', 'o', 'v'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'I', 's', 'a', 'e', 'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'K',
#   'a',
#   'r',
#   't',
#   'a',
#   's',
#   'h',
#   'o',
#   'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'K',
#   'h',
#   'r',
#   'a',
#   'p',
#   'a',
#   't',
#   'y'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'K', 'o', 'l', 'e', 's', 'o', 'v'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'K', 'o', 'n', 'k', 'o', 'v'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'K', 'o', 'n', 'y', 'e', 'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'K',
#   'o',
#   't',
#   'e',
#   't',
#   's',
#   'e',
#   'v'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'K', 'r', 'i', 'k', 'u', 'n'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'K', 'u', 'k', 's', 'o', 'v'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'L', 'a', 'g', 'e', 't', 'k', 'o'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'M',
#   'a',
#   's',
#   'l',
#   'e',
#   'n',
#   'k',
#   'i',
#   'n'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'M', 'y', 's', 'h', 'k', 'i', 'n'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'N',
#   'a',
#   'z',
#   'a',
#   'r',
#   'e',
#   'n',
#   'k',
#   'o'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'N', 'o', 'v', 'i', 'k', 'o', 'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'P',
#   'a',
#   'r',
#   'f',
#   'e',
#   'n',
#   'o',
#   'v'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'P', 'e', 'r', 'o', 'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'P',
#   'o',
#   'l',
#   'i',
#   's',
#   'h',
#   'c',
#   'h',
#   'u',
#   'k'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'P',
#   'o',
#   'l',
#   'i',
#   'v',
#   'o',
#   'd',
#   'a'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'R',
#   'o',
#   's',
#   'h',
#   'c',
#   'h',
#   'i',
#   'n'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'S',
#   'a',
#   'm',
#   'o',
#   't',
#   's',
#   'v',
#   'e',
#   't',
#   'o',
#   'v'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'S', 'a', 's', 's'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'S',
#   'e',
#   'm',
#   'j',
#   'o',
#   'n',
#   'o',
#   'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'S',
#   't',
#   'a',
#   'r',
#   'o',
#   's',
#   't',
#   'i',
#   'n'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   ' ',
#   'T',
#   'a',
#   'r',
#   'a',
#   'b',
#   'r',
#   'i',
#   'n'],
#  ['A', 'n', 'a', 't', 'o', 'l', 'i', ' ', 'Y', 'a', 'r', 'k', 'i', 'n'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'i',
#   'i',
#   ' ',
#   'S',
#   'h',
#   'e',
#   'l',
#   'j',
#   'u',
#   'k',
#   'h',
#   'i',
#   'n'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'y',
#   ' ',
#   'A',
#   'l',
#   'y',
#   'a',
#   'b',
#   'y',
#   'e',
#   'v'],
#  ['A',
#   'n',
#   'a',
#   't',
#   'o',
#   'l',
#   'y',
#   ' ',
#   'M',
#   'i',
#   'k',
#   'h',
#   'a',
#   'y',
#   'l',
#   'o',
#   'v'],
#  ['A',
#   'n',
#   'a',
#   'y',
#   's',
#   'i',
#   ' ',
#   'H',
#   'e',
#   'r',
#   'n',
#   'a',
#   'n',
#   'd',
#   'e',
#   'z'],
#  ['A',
#   'n',
#   'd',
#   'e',
#   'l',
#   'a',
#   ' ',
#   'B',
#   'u',
#   'l',
#   'a',
#   't',
#   'o',
#   'v',
#   'i',
#   'c'],
#  ['A', 'n', 'd', 'e', 'r', 's', ' ', 'A', 'n', 'd', 'e', 'r', 's', 'e', 'n'],
#  ['A',
#   'n',
#   'd',
#   'e',
#   'r',
#   's',
#   ' ',
#   'A',
#   'n',
#   'd',
#   'e',
#   'r',
#   's',
#   's',
#   'o',
#   'n'],
#  ['A', 'n', 'd', 'e', 'r', 's', ' ', 'E', 'k', 's', 't', 'r', 'o', 'm'],
#  ['A',
#   'n',
#   'd',
#   'e',
#   'r',
#   's',
#   ' ',
#   'E',
#   'l',
#   'd',
#   'e',
#   'b',
#   'r',
#   'i',
#   'n',
#   'k'],
#  ['A', 'n', 'd', 'e', 'r', 's', ' ', 'G', 'a', 'r', 'd', 'e', 'r', 'u', 'd'],
#  ['A', 'n', 'd', 'e', 'r', 's', ' ', 'H', 'o', 'l', 'm', 'e', 'r', 't', 'z'],
#  ['A', 'n', 'd', 'e', 'r', 's', ' ', 'J', 'a', 'r', 'l'],
#  ['A', 'n', 'd', 'e', 'r', 's', ' ', 'J', 'a', 'r', 'r', 'y', 'd'],
#  ['A',
#   'n',
#   'd',
#   'e',
#   'r',
#   's',
#   ' ',
#   'M',
#   'a',
#   'r',
#   't',
#   'i',
#   'n',
#   'u',
#   's',
#   ' ',
#   'P',
#   'e',
#   't',
#   'e',
#   'r',
#   's',
#   'e',
#   'n'],
#  ['A',
#   'n',
#   'd',
#   'e',
#   'r',
#   's',
#   ' ',
#   'P',
#   'e',
#   't',
#   'e',
#   'r',
#   ' ',
#   'N',
#   'i',
#   'e',
#   'l',
#   's',
#   'e',
#   'n'],
#  ['A', 'n', 'd', 'e', 'r', 's', ' ', 'P', 'e', 't', 'e', 'r', 's', 'e', 'n'],
#  ['A',
#   'n',
#   'd',
#   'e',
#   'r',
#   's',
#   ' ',
#   'S',
#   'o',
#   'e',
#   'd',
#   'e',
#   'r',
#   'g',
#   'r',
#   'e',
#   'n'],
#  ['A', 'n', 'd', 'e', 'r', 's', 'o', 'n'],
#  ['A',
#   'n',
#   'd',
#   'e',
#   'r',
#   's',
#   'o',
#   'n',
#   ' ',
#   'R',
#   'o',
#   'd',
#   'r',
#   'i',
#   'g',
#   'u',
#   'e',
#   's'],
#  ['A',
#   'n',
#   'd',
#   'i',
#   ' ',
#   'G',
#   'r',
#   ' ',
#   'N',
#   'e',
#   'n',
#   'f',
#   'e',
#   'l',
#   'd',
#   'e',
#   'r'],
#  ['A',
#   'n',
#   'd',
#   'j',
#   'e',
#   'l',
#   'i',
#   'j',
#   'a',
#   ' ',
#   'A',
#   'r',
#   'b',
#   'u',
#   't',
#   'i',
#   'n',
#   'a'],
#  ['A', 'n', 'd', 'o', 'n', ' ', 'N', 'i', 'k', 'o', 'l', 'o', 'v'],
#  ['A', 'n', 'd', 'r', ' ', 'A', 'u', 'f', 'f', 'r', 'a', 'y'],
#  ['A', 'n', 'd', 'r', ' ', 'B', 'e', 'c', 'q', 'u', 'e', 't'],
#  ['A', 'n', 'd', 'r', ' ', 'B', 'e', 'h', 'o', 't', 'e', 'g', 'u', 'y'],
#  ['A', 'n', 'd', 'r', ' ', 'C', 'a', 's', 't', 'a', 'n', 'e', 't'],
#  ['A', 'n', 'd', 'r', ' ', 'C', 'h', 'i', 'l', 'o'],
#  ['A', 'n', 'd', 'r', ' ', 'C', 'o', 'u', 'm', 'a', 'n', 's'],
#  ['A', 'n', 'd', 'r', ' ', 'E', ' ', 'B', 'r', 'u', 'n', 'e', 't'],
#  ['A', 'n', 'd', 'r', ' ', 'F', 'i', 'e', 'r', 'e', 'n', 's'],
#  ['A', 'n', 'd', 'r', ' ', 'F', 'i', 'l', 'i', 'p', 'p', 'i', 'n', 'i'],
#  ['A', 'n', 'd', 'r', ' ', 'G', 'a', 'b', 'o', 'r', 'i', 'a', 'u', 'd'],
#  ['A', 'n', 'd', 'r', ' ', 'G', 'a', 'r', 'd', 'e', 'r', 'e'],
#  ['A', 'n', 'd', 'r', ' ', 'G', 'a', 'u', 'd', 'i', 'n'],
#  ['A',
#   'n',
#   'd',
#   'r',
#   ' ',
#   'H',
#   'e',
#   'n',
#   'r',
#   'i',
#   ' ',
#   'G',
#   'o',
#   'b',
#   'e',
#   'r',
#   't'],
#  ['A', 'n', 'd', 'r', ' ', 'H', 'i', 'g', 'e', 'l', 'i', 'n'],
#  ['A', 'n', 'd', 'r', ' ', 'L', 'a', 'b', 'a', 't', 't', 'u', 't'],
#  ['A', 'n', 'd', 'r', ' ', 'L', 'a', 'u', 's', 'e', 'i', 'g'],
#  ['A', 'n', 'd', 'r', ' ', 'P', 'a', 'r', 'm', 'e', 'n', 't', 'i', 'e', 'r'],
#  ['A', 'n', 'd', 'r', ' ', 'P', 'r', 'e', 'v', 'o', 's', 't'],
#  ['A', 'n', 'd', 'r', ' ', 'R', 'e', 'g', 'a', 'u', 'd'],
#  ['A', 'n', 'd', 'r', ' ', 'R', 'i', 's', 'c', 'h', 'm', 'a', 'n', 'n'],
#  ['A', 'n', 'd', 'r', ' ', 'S', ' ', 'M', 'a', 'z', 'a', 'l', 'i'],
#  ['A', 'n', 'd', 'r', ' ', 'S', 'i', 'x'],
#  ['A', 'n', 'd', 'r', ' ', 'V', 'a', 'n', 'd', 'e', 'l', 'l', 'e'],
#  ['A', 'n', 'd', 'r', ' ', 'V', 'e', 'r', 'c', 'r', 'u', 'y', 's', 's', 'e'],
#  ['A', 'n', 'd', 'r', 'a', 's', ' ', 'B', 'a', 'l', 'c', 'z', 'o'],
#  ['A', 'n', 'd', 'r', 'a', 's', ' ', 'B', 'o', 'd', 'n', 'a', 'r'],
#  ['A', 'n', 'd', 'r', 'a', 's', ' ', 'B', 'o', 't', 'o', 's'],
#  ['A', 'n', 'd', 'r', 'a', 's', ' ', 'H', 'a', 'r', 'g', 'i', 't', 'a', 'y'],
#  ['A',
#   'n',
#   'd',
#   'r',
#   'a',
#   's',
#   ' ',
#   'I',
#   's',
#   't',
#   'v',
#   'a',
#   'n',
#   ' ',
#   'T',
#   ' ',
#   'R',
#   'o'],
#  ['A', 'n', 'd', 'r', 'a', 's', ' ', 'K', 'a', 't', 'o', 'n', 'a'],
#  ['A', 'n', 'd', 'r', 'a', 's', ' ', 'O', 'z', 's', 'v', 'a', 'r'],
#  ['A', 'n', 'd', 'r', 'a', 's', ' ', 'S', 'a', 'l', 'l', 'a', 'y'],
#  ['A', 'n', 'd', 'r', 'a', 's', ' ', 'S', 'i', 'k', 'e'],
#  ['A', 'n', 'd', 'r', 'a', 's', ' ', 'S', 'z', 'e', 'n', 't', 'e'],
#  ['A',
#   'n',
#   'd',
#   'r',
#   'e',
#   ' ',
#   'A',
#   'l',
#   'f',
#   'o',
#   'n',
#   's',
#   ' ',
#   'N',
#   'o',
#   'y',
#   'e',
#   'l',
#   'l',
#   'e'],
#  ['A', 'n', 'd', 'r', 'e', ' ', 'B', 'a', 'r', 'r', 'a', 'i', 's'],
#  ['A', 'n', 'd', 'r', 'e', ' ', 'B', 'o', 'n', 'i', 'n'],
#  ['A', 'n', 'd', 'r', 'e', ' ', 'B', 'u', 'f', 'f', 'i', 'e', 'r', 'e'],
#  ['A', 'n', 'd', 'r', 'e', ' ', 'C', 'r', 'u', 'z'],
#  ['A',
#   'n',
#   'd',
#   'r',
#   'e',
#   ' ',
#   'D',
#   'o',
#   'm',
#   'i',
#   'n',
#   'g',
#   'o',
#   's',
#   ' ',
#   'S',
#   'i',
#   'l',
#   'v',
#   'a'],
#  ['A', 'n', 'd', 'r', 'e', ' ', 'E', 'h', 'r', 'e', 'n', 'b', 'e', 'r', 'g'],
#  ['A', 'n', 'd', 'r', 'e', ' ', 'E', 'v', 'e', 'n'],
#  ['A',
#   'n',
#   'd',
#   'r',
#   'e',
#   ' ',
#   'F',
#   'e',
#   'l',
#   'i',
#   'p',
#   'p',
#   'e',
#   ' ',
#   'F',
#   'e',
#   'r',
#   'r',
#   'e',
#   'i',
#   'r',
#   'a'],
#  ['A',
#   'n',
#   'd',
#   'r',
#   'e',
#   ' ',
#   'F',
#   'l',
#   'o',
#   'r',
#   's',
#   'c',
#   'h',
#   'u',
#   'e',
#   't',
#   'z'],
#  ['A',
#   'n',
#   'd',
#   'r',
#   'e',
#   ' ',
#   'G',
#   'e',
#   'r',
#   'h',
#   'a',
#   'r',
#   'd',
#   ' ',
#   'W',
#   'o',
#   'h',
#   'l',
#   'l',
#   'e',
#   'b',
#   'e'],
#  ['A', 'n', 'd', 'r', 'e', ' ', 'G', 'i', 'r', 'i', 'a', 't'],
#  ['A', 'n', 'd', 'r', 'e', ' ', 'H', 'e', 'l', 'l', 'e', 'r'],
#  ['A',
#   'n',
#   'd',
#   'r',
#   'e',
#   ' ',
#   'J',
#   'o',
#   'h',
#   'a',
#   'n',
#   'n',
#   'p',
#   'e',
#   't',
#   'e',
#   'r'],
#  ['A', 'n', 'd', 'r', 'e', ' ', 'L', 'a', 'n', 'g', 'e'],
#  ['A', 'n', 'd', 'r', 'e', ' ', 'L', 'u', 'i', 'z'],
#  ['A',
#   'n',
#   'd',
#   'r',
#   'e',
#   ' ',
#   'L',
#   'u',
#   'i',
#   'z',
#   ' ',
#   'F',
#   'e',
#   'r',
#   'r',
#   'e',
#   'i',
#   'r',
#   'a'],
#  ['A', 'n', 'd', 'r', 'e', ' ', 'M', 'o', 'c', 'c', 'a', 'n', 'd'],
#  ...]

# %%
# Numerical-encoded sequences
unig_seq = [list(unigram2idx[gram] for gram in name) for name in unig_corpus]
bigr_seq = [list(bigram2idx[gram] for gram in name) for name in bigr_corpus]
trig_seq = [list(trigram2idx[gram] for gram in name)
            for name in trig_corpus]
